# %%
import shutil
from dataclasses import dataclass
from functools import partial
from pathlib import Path
from typing import List, Optional, Union, Iterable

import matplotlib.pyplot as plt
import pandas as pd

from utils.helper import mturk_localize, _subpath_after


@dataclass
class TaskConfig:
    resp_col: str  # e.g. "resp.keys"
    rt_col: Optional[str]  # e.g. "resp.rt" or None if no RT
    trial_start_col: str  # e.g. "TrialIntro.started"

    act_cols: List[str]  # e.g. ["act3", "act4"]
    stim_cols: List[str]  # e.g. ["stim1", "stim2", "stim3", "stim4"]
    act_indices: List[int]

    features: List[str]

    task_trial_csv: str
    task_meta_csv: str
    task_name: str = "1back"


def make_unique_columns(cols: Iterable) -> List[str]:
    """
    Make column names unique by appending suffixes: 'resp.rt', 'resp.rt__1', ...
    Also converts NaNs to empty strings.
    """
    seen = {}
    out = []
    for c in cols:
        if pd.isna(c):
            c = ""
        c = str(c)
        if c not in seen:
            seen[c] = 0
            out.append(c)
        else:
            seen[c] += 1
            out.append(f"{c}_{seen[c]}")
    return out


def load_blocks_from_csv(csv_path, header_token="Welcome.started"):
    """
    Read the raw PsychoPy MTurk CSV that has repeated header rows
    and split it into blocks. Each block gets its *own* header row
    (the row whose first cell == header_token).

    Returns a list of per-block DataFrames.
    """
    csv_path = Path(csv_path)
    raw = pd.read_csv(csv_path, header=None)

    # Find header rows
    header_mask = raw.iloc[:, 0] == header_token
    header_idx = list(raw.index[header_mask])
    header_idx.append(len(raw))

    blocks = []
    for start, end in zip(header_idx[:-1], header_idx[1:]):
        block = raw.iloc[start:end].reset_index(drop=True)
        if block.shape[0] <= 1:
            continue  # header only, no data

        header_row = block.iloc[0].tolist()
        data = block.iloc[1:].copy()
        data.columns = header_row

        last_real_col = 0
        for i, col in enumerate(header_row):
            if not pd.isna(col) and str(col).strip() != "":
                last_real_col = i

        data = data.iloc[:, : last_real_col + 1]
        header_row = header_row[:last_real_col + 1]
        data = data.iloc[:, :-3]  # last 2 columns are worker ID and time
        header_row = header_row[:-3]
        data.columns = make_unique_columns(header_row)
        data = data.dropna(how="all")

        if not data.empty:
            blocks.append(data)

    return blocks


def split_by_worker_and_exp(
        csv_path,
        out_dir,
        worker_list=None,
        task_list=None,
        header_token="Welcome.started",
):
    """
    Read a CSV with columns including 'workerId' and 'expName',
    and save one CSV per (workerId, expName) group.
    """
    csv_path = Path(csv_path)
    out_dir = Path(out_dir)
    out_dir.mkdir(parents=True, exist_ok=True)

    blocks = load_blocks_from_csv(csv_path, header_token=header_token)
    common_cols = blocks[0].columns
    print("Columns to be used across all experiments:")
    print(common_cols)
    aligned_blocks = [b.reindex(columns=common_cols) for b in blocks]

    # Concatenate all blocks into one big DataFrame
    df = pd.concat(aligned_blocks, ignore_index=True)
    header = list(df.columns)

    embedded_header_rows = df.apply(
        lambda row: any(str(val).strip() in header for val in row),
        axis=1
    )
    df = df[~embedded_header_rows]

    clean_df = df[
        df["workerId"].notna()
        & (df["workerId"].str.strip() != "")
        & (df["workerId"] != "workerId")
        & (df["expName"].notna())
        ]
    if worker_list:
        clean_df = clean_df[clean_df["workerId"].isin(worker_list)]

    if task_list:
        clean_df = clean_df[clean_df["expName"].isin(task_list)]

    if "workerId" not in df.columns or "expName" not in df.columns:
        raise ValueError("CSV must contain 'workerId' and 'expName' columns")

    for (worker, exp), sub_df in clean_df.groupby(["workerId", "expName"], dropna=False):
        fname = f"{worker}_{exp}.csv"
        sub_df.to_csv(out_dir / fname, index=False)
        print(f"Saved {len(sub_df)} rows to {out_dir / fname}")
    return

# %%
def analyze_accuracy(
        behaviour_df: pd.DataFrame,
        trial_df: pd.DataFrame,
        meta_df: pd.DataFrame,
        task_config: TaskConfig,
):
    n_frames = len(task_config.stim_cols)
    if task_config.trial_start_col not in behaviour_df.columns:
        raise ValueError(f"Column '{task_config.trial_start_col}' not found in behaviour_df")

    meta_lookup = meta_df.set_index('filename').to_dict(orient="index")
    trials = []
    details = []
    trial_start_indices = behaviour_df.index[
        behaviour_df[TRIAL_START_COL].notna()
    ].tolist()
    n_trials = min(len(trial_start_indices), len(trial_df))

    if len(trial_start_indices) != len(trial_df):
        print(
            f"Warning: #trial starts in log ({len(trial_start_indices)}) != "
            f"#rows in condition file ({len(trial_df)}). Using the minimum of the two."
        )

    for i in range(n_trials):
        start_idx = trial_start_indices[i]
        resp_indices = [r_i + start_idx - 1 for r_i in task_config.act_indices]
        act_idx = start_idx + n_frames  # row containing correct answers

        if act_idx >= len(behaviour_df):
            break

        responses = behaviour_df.loc[resp_indices, task_config.resp_col].tolist()
        if task_config.rt_col in behaviour_df.columns:
            rts = behaviour_df.loc[resp_indices, task_config.rt_col].tolist()
        else:
            rts = [None] * len(resp_indices)

        # correct answers from the behavior log
        correct_answers = behaviour_df.loc[act_idx, task_config.act_cols].tolist()
        cond_row = trial_df.iloc[i]
        assert correct_answers == trial_df.loc[
            i, task_config.act_cols].tolist(), f'{correct_answers} vs. {trial_df.loc[i, task_config.act_cols].tolist()}'

        # session info from condition file (if exists)
        session = cond_row["session"] if "session" in trial_df.columns else None

        # compute correctness & missing
        trial_correct = []
        trial_missing = 0
        for r, c in zip(responses, correct_answers):
            r_stripped = None if pd.isna(r) else str(r).strip()
            c_stripped = None if pd.isna(c) else str(c).strip()

            if r_stripped in (None, ""):
                trial_missing += 1

            if r_stripped is None or c_stripped is None or r_stripped == "":
                trial_correct.append(False)
            else:
                trial_correct.append(r_stripped.lower() == c_stripped.lower())

        n_correct = sum(trial_correct)
        n_total = len(trial_correct)
        accuracy = n_correct / n_total if n_total > 0 else float("nan")

        trials.append({
            "trial_id": i + 1,
            "session": session,
            "n_correct": n_correct,
            "n_total": n_total,
            "accuracy": accuracy,
            "n_missing": trial_missing,
        })

        # detailed per-response info
        for j, (idx, r, rt, c, corr) in enumerate(
                zip(resp_indices, responses, rts, correct_answers, trial_correct), start=1
        ):
            r_stripped = None if pd.isna(r) else str(r).strip()
            is_missing = (r_stripped in (None, ""))

            # current stimulus is frame j+1 -> 
            stim_col = f"stim{j + 1}"
            stim_path = Path(cond_row.get(stim_col, None))
            stim_path = stim_path.with_name(stim_path.name.lstrip("_"))
            meta_row = meta_lookup[stim_path]
            feature_values = dict()
            for feat in task_config.features:
                feature_values[feat] = meta_row.get(feat, None)

            details_row = {
                "trial_id": i + 1,
                "session": session,
                "resp_index": j,
                "csv_row": idx,
                "response": r,
                "rt": rt,
                "correct_answer": c,
                "is_correct": corr,
                "is_missing": is_missing,
                "stim_col": stim_col,
                "stim_path": stim_path,
            }
            details_row.update(feature_values)
            details.append(details_row)

    summary_df = pd.DataFrame(trials)
    detail_df = pd.DataFrame(details)

    # Overall accuracies
    overall_trial_accuracy = summary_df["accuracy"].mean()
    overall_frame_accuracy = detail_df["is_correct"].mean()

    print(f"\nAnalyzed {len(trial_df)} trials")
    print(f"Overall (mean per-trial) accuracy: {overall_trial_accuracy:.2%}")
    print(f"Overall (per-frame) accuracy:      {overall_frame_accuracy:.2%}\n")
    return summary_df, detail_df


def task_analysis(
        summary_df: pd.DataFrame,
        detail_df: pd.DataFrame,
        task_config: TaskConfig,
        output_prefix: Path,
):
    # -------- Session-level summaries --------
    if "session" in summary_df.columns and summary_df["session"].notna().any():
        # missing responses per session
        missing_per_session = detail_df.groupby("session")["is_missing"].sum().rename("n_missing").reset_index()

        # frame-wise accuracy per session
        frame_acc_per_session = detail_df.groupby("session")["is_correct"].mean().rename("frame_accuracy")

        # trial-wise accuracy per session
        trial_acc_per_session = summary_df.groupby("session")["accuracy"].mean().rename("trial_accuracy")

        session_summary = (
            summary_df.groupby("session")["trial_id"]
            .nunique()
            .rename("n_trials")
            .to_frame()
            .join(frame_acc_per_session)
            .join(trial_acc_per_session)
            .join(missing_per_session.set_index("session"))
            .reset_index()
        )

        print("Session-level summary:")
        print(session_summary.to_string(index=False))
        print()
    else:
        session_summary = pd.DataFrame()
        print("No 'session' information available for session-level summary.\n")

    feature_session_summaries = {}

    for feat in task_config.features:
        feat_df = detail_df[detail_df[feat].notna()].copy()
        feat_session_summary = (
            feat_df.groupby(["session", feat])
            .agg(
                n_samples=("is_correct", "size"),
                accuracy=("is_correct", "mean"),
                n_missing=("is_missing", "sum"),
            )
            .reset_index()
        )
        feature_session_summaries[feat] = feat_session_summary

        print(f"Per-{feat} accuracy per session:")
        print(feat_session_summary.to_string(index=False))
        print()

    # -------- RT distribution across all sessions --------
    if "rt" in detail_df.columns and detail_df["rt"].notna().any():
        rt_series = pd.to_numeric(detail_df["rt"], errors="coerce").dropna()
        if not rt_series.empty:
            rt_fig_path = output_prefix / "rt_distribution.png"

            plt.figure(figsize=(6, 4))
            plt.hist(rt_series, bins=30)
            plt.xlabel("Response time (s)")
            plt.ylabel("Count")
            plt.title(f"{task_config.task_name}: RT distribution (all sessions)")
            plt.tight_layout()
            plt.savefig(rt_fig_path, dpi=150)
            plt.close()

            print(f"Saved RT distribution plot to: {rt_fig_path}")
        elif rt_series.empty:
            print("No valid RT values found; RT distribution plot not generated.")
    else:
        print("Column for RT not found or empty; RT distribution plot not generated.")

    # -------- Save outputs --------
    if output_prefix is not None:
        trial_path = output_prefix / "trial_accuracy.csv"
        detail_path = output_prefix / "detailed_accuracy.csv"
        session_path = output_prefix / "session_summary.csv"

        summary_df.to_csv(trial_path, index=False)
        detail_df.to_csv(detail_path, index=False)
        session_summary.to_csv(session_path, index=False)

        print(f"Saved per-trial accuracy to:    {trial_path}")
        print(f"Saved detailed responses to:    {detail_path}")
        print(f"Saved per-session summary to:   {session_path}")

        # Save per-feature summaries
        for feat, feat_df in feature_session_summaries.items():
            feat_path = output_prefix / f"session_{feat}_accuracy.csv"
            feat_df.to_csv(feat_path, index=False)
            print(f"Saved per-session/{feat} stats to: {feat_path}")
    return {
        "trial_summary": summary_df,
        "detail": detail_df,
        "session_summary": session_summary,
        "feature_session_summaries": feature_session_summaries,
    }

# %%
def analyze_all_subjects(
        behavior_dir,
        trial_df,
        meta_df,
        task_config: TaskConfig,
        pattern="Responses - 1back_*.csv",
):
    """
    Iterate over all response files in `behavior_dir` matching `pattern`
    and run analyze_accuracy on each, using the provided TaskConfig.

    Each subject's outputs will be saved next to their own response file.
    """
    behavior_dir = Path(behavior_dir)
    files = sorted(behavior_dir.glob(pattern))

    if not files:
        print(f"No files matching pattern '{pattern}' found in {behavior_dir}")
        return

    print(f"Found {len(files)} files to analyze in {behavior_dir}:")
    for f in files:
        print(f"  - {f.name}")

    for f in files:
        worker = f.stem.split('_')[0]
        print(f"\n=== Analyzing {worker} performance on ({task_config.task_name}) ===")
        # Create a subdirectory for this worker
        worker_dir = behavior_dir / worker
        worker_dir.mkdir(exist_ok=True, parents=True)

        # Copy raw CSV into the worker folder
        raw_copy_path = worker_dir / f.name
        shutil.copy(f, raw_copy_path)

        behavior_df = pd.read_csv(f)
        summary_df, detail_df = analyze_accuracy(
            behaviour_df=behavior_df,
            trial_df=trial_df,
            meta_df=meta_df,
            task_config=task_config,
        )
        summary = task_analysis(
            summary_df=summary_df,
            detail_df=detail_df,
            task_config=task_config,
            output_prefix=worker_dir,
        )
    print("\n✅ Done running analysis for all available response files.")
    return

# %%
RESP_COL = "resp.keys"
RT_COL = "resp.rt"
TRIAL_START_COL = "TrialIntro.started"

project_dir = Path.cwd().parent
data_dir = project_dir / 'data'
resource_dir = project_dir / 'resources'

# %%
one_back_config = TaskConfig(
    resp_col=RESP_COL,
    rt_col=RT_COL,
    trial_start_col=TRIAL_START_COL,

    act_cols=["act2", "act3", "act4", "act5", "act6"],
    stim_cols=["stim1", "stim2", "stim3", "stim4", "stim5", "stim6"],
    act_indices=[2, 3, 4, 5, 6],

    features=['category'],

    task_trial_csv='1back_category_trials.csv',
    task_meta_csv='1back_category_subset.csv',
    task_name="1back_category",
)

split_by_worker_and_exp(
    data_dir / 'responses.csv',
    data_dir,
    worker_list={
        'A1DTW8MSLPXOK4',
        'A2KW9RKCCLIGA9',
        'A2E0L82O40LXJJ',
        'AURYD2FH3FUOQ',
        'AVHLOE4JVMAQ6',
        'A2MR2WI6L8IPDA',
        'A1JST8K4QOV57L',
        'A3HX4G5VCYNE6G',
        'A2EDS2STUK23FT',
        'AJMDCYYH1TZD2',
    },
    task_list=['1back_category']
)
meta_df = pd.read_csv(resource_dir / one_back_config.task_meta_csv)
meta_df['filename'] = meta_df['filename'].apply(
    partial(mturk_localize, Path('images'))
)

analyze_all_subjects(
    behavior_dir=data_dir,
    trial_df=pd.read_csv(resource_dir / one_back_config.task_trial_csv),
    meta_df=meta_df,
    task_config=one_back_config,
    pattern=f'*_{one_back_config.task_name}.csv'
)
# Out:
# Columns to be used across all experiments:
# Index(['Welcome.started', 'Welcome.stopped', 'welcomeKey.keys',
#        'welcomeKey.rt', 'welcomeKey.duration', 'workerId', 'mturkLink', 'date',
#        'expName', 'psychopyVersion', 'OS', 'frameRate', 'Globals.started',
#        'Globals.stopped', 'SessionIntro.started', 'SessionIntro.stopped',
#        'sessKey.keys', 'sessKey.rt', 'sessKey.duration', 'TrialIntro.started',
#        'TrialIntro.stopped', 'trialKey.keys', 'trialKey.rt',
#        'trialKey.duration', 'Frame.started', 'Frame.stopped', 'resp.keys',
#        'frames.thisRepN', 'frames.thisTrialN', 'frames.thisN',
#        'frames.thisIndex', 'frames.ran', 'trials.thisRepN',
#        'trials.thisTrialN', 'trials.thisN', 'trials.thisIndex', 'trials.ran',
#        'session', 'stim1', 'stim2', 'stim3', 'stim4', 'stim5', 'stim6', 'act2',
#        'act3', 'act4', 'act5', 'act6', 'resp.rt', 'resp.duration',
#        'ITI.started', 'ITI.stopped', 'itiKey.keys', 'Thanks.started',
#        'Thanks.stopped', 'thanksKey.keys', 'thanksKey.rt',
#        'thanksKey.duration'],
#       dtype='object')
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1DTW8MSLPXOK4_1back_category.csv
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2EDS2STUK23FT_1back_category.csv
# Saved 312 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2KW9RKCCLIGA9_1back_category.csv
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A3HX4G5VCYNE6G_1back_category.csv
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AJMDCYYH1TZD2_1back_category.csv
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AURYD2FH3FUOQ_1back_category.csv
# Found 6 files to analyze in /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data:
#   - A1DTW8MSLPXOK4_1back_category.csv
#   - A2EDS2STUK23FT_1back_category.csv
#   - A2KW9RKCCLIGA9_1back_category.csv
#   - A3HX4G5VCYNE6G_1back_category.csv
#   - AJMDCYYH1TZD2_1back_category.csv
#   - AURYD2FH3FUOQ_1back_category.csv
#
# === Analyzing A1DTW8MSLPXOK4 performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 31.20%
# Overall (per-frame) accuracy:      31.20%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.27            0.27         55
#        2        20            0.37            0.37         35
#        3        20            0.26            0.26         49
#        4        20            0.29            0.29         42
#        5        20            0.37            0.37         33
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.294118          8
#        1    Boats         14  0.428571          4
#        1     Cars         23  0.260870         17
#        1    Faces         13  0.076923          9
#        1   Fruits         18  0.333333          6
#        1   Planes         15  0.200000         11
#        2  Animals         15  0.466667          4
#        2    Boats         13  0.307692          3
#        2     Cars         21  0.238095         14
#        2    Faces         12  0.333333          3
#        2   Fruits         20  0.450000          7
#        2   Planes         19  0.421053          4
#        3  Animals          9  0.444444          3
#        3    Boats         15  0.133333          8
#        3     Cars          8  0.125000          3
#        3    Faces         21  0.380952         10
#        3   Fruits         19  0.157895         11
#        3   Planes         28  0.285714         14
#        4  Animals         25  0.200000         11
#        4    Boats          6  0.166667          3
#        4     Cars         20  0.250000          8
#        4    Faces         14  0.642857          3
#        4   Fruits         11  0.090909          7
#        4   Planes         24  0.333333         10
#        5  Animals         13  0.076923          6
#        5    Boats          8  0.625000          2
#        5     Cars         27  0.259259         10
#        5    Faces         15  0.533333          3
#        5   Fruits         18  0.388889          7
#        5   Planes         19  0.473684          5
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1DTW8MSLPXOK4/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1DTW8MSLPXOK4/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1DTW8MSLPXOK4/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1DTW8MSLPXOK4/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1DTW8MSLPXOK4/session_category_accuracy.csv
#
# === Analyzing A2EDS2STUK23FT performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 53.00%
# Overall (per-frame) accuracy:      53.00%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.33            0.33         61
#        2        20            0.55            0.55         39
#        3        20            0.59            0.59          9
#        4        20            0.57            0.57         10
#        5        20            0.61            0.61          7
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.235294         11
#        1    Boats         14  0.285714          8
#        1     Cars         23  0.478261         12
#        1    Faces         13  0.307692          9
#        1   Fruits         18  0.222222         14
#        1   Planes         15  0.400000          7
#        2  Animals         15  0.200000         11
#        2    Boats         13  0.692308          4
#        2     Cars         21  0.523810          9
#        2    Faces         12  0.583333          5
#        2   Fruits         20  0.700000          5
#        2   Planes         19  0.578947          5
#        3  Animals          9  0.444444          3
#        3    Boats         15  0.533333          2
#        3     Cars          8  1.000000          0
#        3    Faces         21  0.666667          0
#        3   Fruits         19  0.473684          3
#        3   Planes         28  0.571429          1
#        4  Animals         25  0.440000          3
#        4    Boats          6  1.000000          0
#        4     Cars         20  0.700000          1
#        4    Faces         14  0.428571          3
#        4   Fruits         11  0.636364          1
#        4   Planes         24  0.541667          2
#        5  Animals         13  0.769231          0
#        5    Boats          8  0.500000          2
#        5     Cars         27  0.555556          2
#        5    Faces         15  0.800000          1
#        5   Fruits         18  0.444444          0
#        5   Planes         19  0.631579          2
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2EDS2STUK23FT/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2EDS2STUK23FT/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2EDS2STUK23FT/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2EDS2STUK23FT/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2EDS2STUK23FT/session_category_accuracy.csv
#
# === Analyzing A2KW9RKCCLIGA9 performance on (1back_category) ===
# Warning: #trial starts in log (45) != #rows in condition file (100). Using the minimum of the two.
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 4.09%
# Overall (per-frame) accuracy:      4.09%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.08            0.08         89
#        2        20            0.01            0.01         98
#        3         4            0.00            0.00         19
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.000000         17
#        1    Boats         14  0.142857         11
#        1     Cars         23  0.130435         18
#        1    Faces         13  0.153846         11
#        1   Fruits         18  0.000000         18
#        1   Planes         15  0.066667         14
#        2  Animals         15  0.000000         15
#        2    Boats         13  0.000000         13
#        2     Cars         21  0.000000         21
#        2    Faces         12  0.000000         12
#        2   Fruits         20  0.050000         18
#        2   Planes         19  0.000000         19
#        3  Animals          1  0.000000          0
#        3    Boats          7  0.000000          7
#        3     Cars          2  0.000000          2
#        3    Faces          3  0.000000          3
#        3   Fruits          3  0.000000          3
#        3   Planes          4  0.000000          4
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2KW9RKCCLIGA9/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2KW9RKCCLIGA9/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2KW9RKCCLIGA9/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2KW9RKCCLIGA9/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2KW9RKCCLIGA9/session_category_accuracy.csv
#
# === Analyzing A3HX4G5VCYNE6G performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 68.00%
# Overall (per-frame) accuracy:      68.00%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.66            0.66         23
#        2        20            0.67            0.67         14
#        3        20            0.71            0.71         13
#        4        20            0.67            0.67         10
#        5        20            0.69            0.69         12
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.411765          5
#        1    Boats         14  0.714286          2
#        1     Cars         23  0.652174          7
#        1    Faces         13  0.769231          3
#        1   Fruits         18  0.722222          3
#        1   Planes         15  0.733333          3
#        2  Animals         15  0.600000          1
#        2    Boats         13  0.846154          1
#        2     Cars         21  0.714286          4
#        2    Faces         12  0.666667          3
#        2   Fruits         20  0.650000          3
#        2   Planes         19  0.578947          2
#        3  Animals          9  0.444444          1
#        3    Boats         15  0.666667          2
#        3     Cars          8  0.875000          1
#        3    Faces         21  0.857143          2
#        3   Fruits         19  0.736842          3
#        3   Planes         28  0.642857          4
#        4  Animals         25  0.560000          2
#        4    Boats          6  0.666667          1
#        4     Cars         20  0.800000          1
#        4    Faces         14  0.785714          1
#        4   Fruits         11  0.545455          1
#        4   Planes         24  0.666667          4
#        5  Animals         13  0.615385          3
#        5    Boats          8  0.750000          1
#        5     Cars         27  0.777778          1
#        5    Faces         15  0.800000          2
#        5   Fruits         18  0.555556          2
#        5   Planes         19  0.631579          3
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A3HX4G5VCYNE6G/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A3HX4G5VCYNE6G/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A3HX4G5VCYNE6G/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A3HX4G5VCYNE6G/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A3HX4G5VCYNE6G/session_category_accuracy.csv
#
# === Analyzing AJMDCYYH1TZD2 performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 38.00%
# Overall (per-frame) accuracy:      38.00%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.30            0.30         38
#        2        20            0.39            0.39         23
#        3        20            0.37            0.37         23
#        4        20            0.40            0.40         20
#        5        20            0.44            0.44         23
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.352941          5
#        1    Boats         14  0.285714          7
#        1     Cars         23  0.173913          7
#        1    Faces         13  0.230769          8
#        1   Fruits         18  0.277778          9
#        1   Planes         15  0.533333          2
#        2  Animals         15  0.533333          5
#        2    Boats         13  0.384615          4
#        2     Cars         21  0.238095          6
#        2    Faces         12  0.416667          2
#        2   Fruits         20  0.350000          3
#        2   Planes         19  0.473684          3
#        3  Animals          9  0.555556          1
#        3    Boats         15  0.400000          4
#        3     Cars          8  0.000000          2
#        3    Faces         21  0.476190          6
#        3   Fruits         19  0.263158          5
#        3   Planes         28  0.392857          5
#        4  Animals         25  0.440000          5
#        4    Boats          6  0.500000          1
#        4     Cars         20  0.250000          6
#        4    Faces         14  0.571429          1
#        4   Fruits         11  0.454545          2
#        4   Planes         24  0.333333          5
#        5  Animals         13  0.615385          3
#        5    Boats          8  0.625000          2
#        5     Cars         27  0.481481          5
#        5    Faces         15  0.200000          6
#        5   Fruits         18  0.333333          3
#        5   Planes         19  0.473684          4
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AJMDCYYH1TZD2/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AJMDCYYH1TZD2/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AJMDCYYH1TZD2/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AJMDCYYH1TZD2/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AJMDCYYH1TZD2/session_category_accuracy.csv
#
# === Analyzing AURYD2FH3FUOQ performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 76.40%
# Overall (per-frame) accuracy:      76.40%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.68            0.68         13
#        2        20            0.77            0.77          7
#        3        20            0.78            0.78         13
#        4        20            0.72            0.72         15
#        5        20            0.87            0.87          5
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.647059          2
#        1    Boats         14  0.428571          3
#        1     Cars         23  0.782609          1
#        1    Faces         13  0.692308          2
#        1   Fruits         18  0.833333          2
#        1   Planes         15  0.600000          3
#        2  Animals         15  0.600000          1
#        2    Boats         13  0.846154          1
#        2     Cars         21  0.761905          4
#        2    Faces         12  0.916667          0
#        2   Fruits         20  0.900000          0
#        2   Planes         19  0.631579          1
#        3  Animals          9  0.444444          3
#        3    Boats         15  0.600000          1
#        3     Cars          8  0.875000          1
#        3    Faces         21  0.714286          4
#        3   Fruits         19  1.000000          0
#        3   Planes         28  0.857143          4
#        4  Animals         25  0.680000          4
#        4    Boats          6  0.666667          2
#        4     Cars         20  0.750000          1
#        4    Faces         14  0.785714          1
#        4   Fruits         11  0.727273          2
#        4   Planes         24  0.708333          5
#        5  Animals         13  0.692308          1
#        5    Boats          8  0.750000          1
#        5     Cars         27  0.925926          1
#        5    Faces         15  0.933333          0
#        5   Fruits         18  0.888889          1
#        5   Planes         19  0.894737          1
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AURYD2FH3FUOQ/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AURYD2FH3FUOQ/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AURYD2FH3FUOQ/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AURYD2FH3FUOQ/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AURYD2FH3FUOQ/session_category_accuracy.csv
#
# ✅ Done running analysis for all available response files.

# %%
inter_config = TaskConfig(
    resp_col=RESP_COL,
    rt_col=RT_COL,
    trial_start_col=TRIAL_START_COL,

    act_cols=["act3", "act4"],
    act_indices=[3, 4],
    stim_cols=["stim1", "stim2", "stim3", "stim4"],
    features=['pos_1b', 'obj'],

    task_trial_csv='interdms_position_identity_trials.csv',
    task_meta_csv='interdms_position_identity_subset.csv',
    task_name="interdms_position_identity",
)

split_by_worker_and_exp(
    data_dir / 'responses.csv',
    data_dir,
    worker_list=[
        'A1P557XDQ2SID7',
        'A16MEV9DI9VMAW',
        'A2UZP2FRACKPK1',
        'A14BJDBO83A5E0',
        'A1JST8K4QOV57L',
        'A1Z0G5SV4PZDUN',
        'A1NZ3TZGHPTS62',
        'A1JWRIHQLAMP6N',
        'AP8HKHQ3GP91K'
    ],
    task_list=['interdms_position_identity']
)
meta_df = pd.read_csv(resource_dir / inter_config.task_meta_csv)

meta_df['filename'] = meta_df['filename'].apply(
    partial(mturk_localize, Path('images'))
)

analyze_all_subjects(
    behavior_dir=data_dir,
    trial_df=pd.read_csv(resource_dir / inter_config.task_trial_csv),
    meta_df=meta_df,
    task_config=inter_config,
    pattern=f'*_{inter_config.task_name}.csv'
)
# Out:
# Columns to be used across all experiments:
# Index(['Welcome.started', 'Welcome.stopped', 'welcomeKey.keys',
#        'welcomeKey.rt', 'welcomeKey.duration', 'workerId', 'mturkLink', 'date',
#        'expName', 'psychopyVersion', 'OS', 'frameRate', 'Globals.started',
#        'Globals.stopped', 'SessionIntro.started', 'SessionIntro.stopped',
#        'sessKey.keys', 'sessKey.rt', 'sessKey.duration', 'TrialIntro.started',
#        'TrialIntro.stopped', 'trialKey.keys', 'trialKey.rt',
#        'trialKey.duration', 'Frame.started', 'Frame.stopped', 'resp.keys',
#        'frames.thisRepN', 'frames.thisTrialN', 'frames.thisN',
#        'frames.thisIndex', 'frames.ran', 'trials.thisRepN',
#        'trials.thisTrialN', 'trials.thisN', 'trials.thisIndex', 'trials.ran',
#        'session', 'stim1', 'stim2', 'stim3', 'stim4', 'stim5', 'stim6', 'act2',
#        'act3', 'act4', 'act5', 'act6', 'resp.rt', 'resp.duration',
#        'ITI.started', 'ITI.stopped', 'itiKey.keys', 'Thanks.started',
#        'Thanks.stopped', 'thanksKey.keys', 'thanksKey.rt',
#        'thanksKey.duration'],
#       dtype='object')
# Saved 504 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A16MEV9DI9VMAW_interdms_position_identity.csv
# Saved 1008 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1JST8K4QOV57L_interdms_position_identity.csv
# Saved 504 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1JWRIHQLAMP6N_interdms_position_identity.csv
# Saved 1008 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1NZ3TZGHPTS62_interdms_position_identity.csv
# Saved 504 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1Z0G5SV4PZDUN_interdms_position_identity.csv
# Saved 504 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AP8HKHQ3GP91K_interdms_position_identity.csv
# Found 6 files to analyze in /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data:
#   - A16MEV9DI9VMAW_interdms_position_identity.csv
#   - A1JST8K4QOV57L_interdms_position_identity.csv
#   - A1JWRIHQLAMP6N_interdms_position_identity.csv
#   - A1NZ3TZGHPTS62_interdms_position_identity.csv
#   - A1Z0G5SV4PZDUN_interdms_position_identity.csv
#   - AP8HKHQ3GP91K_interdms_position_identity.csv
#
# === Analyzing A16MEV9DI9VMAW performance on (interdms_position_identity) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 66.50%
# Overall (per-frame) accuracy:      66.50%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20           0.550           0.550          4
#        2        20           0.550           0.550          2
#        3        20           0.675           0.675          2
#        4        20           0.825           0.825          1
#        5        20           0.725           0.725          0
#
# Per-pos_1b accuracy per session:
#  session  pos_1b  n_samples  accuracy  n_missing
#        1       1          3  0.666667          1
#        1       2          3  0.333333          0
#        1       3          4  0.750000          1
#        1       4          1  0.000000          1
#        1       5         19  0.631579          0
#        1       6          2  0.500000          0
#        1       7          1  1.000000          0
#        1       8          5  0.000000          1
#        1       9          2  1.000000          0
#        2       1          1  1.000000          0
#        2       2          2  0.500000          0
#        2       3          4  1.000000          0
#        2       4          1  1.000000          0
#        2       5         19  0.368421          1
#        2       6          1  1.000000          0
#        2       7          6  0.500000          1
#        2       8          4  0.500000          0
#        2       9          2  1.000000          0
#        3       1          2  0.500000          1
#        3       2          1  1.000000          0
#        3       3          5  0.800000          0
#        3       4          4  1.000000          0
#        3       5         15  0.466667          1
#        3       6          5  0.600000          0
#        3       7          5  1.000000          0
#        3       8          2  1.000000          0
#        3       9          1  0.000000          0
#        4       1          3  1.000000          0
#        4       2          1  1.000000          0
#        4       3          3  0.666667          0
#        4       4          7  0.714286          0
#        4       5         15  0.866667          0
#        4       6          3  1.000000          0
#        4       7          5  0.800000          0
#        4       8          2  1.000000          0
#        4       9          1  0.000000          1
#        5       1          1  0.000000          0
#        5       2          1  1.000000          0
#        5       3          3  0.333333          0
#        5       4          1  1.000000          0
#        5       5         24  0.666667          0
#        5       6          4  1.000000          0
#        5       7          3  1.000000          0
#        5       8          1  1.000000          0
#        5       9          2  1.000000          0
#
# Per-obj accuracy per session:
#  session                      obj  n_samples  accuracy  n_missing
#        1          Apple_Fruit_obj          2  0.000000          0
#        1                   Beetle          1  0.000000          0
#        1                  GORILLA          1  1.000000          0
#        1                 MQUEEN_L          1  0.000000          0
#        1           Strawberry_obj          1  1.000000          0
#        1                 TURTLE_L          1  0.000000          0
#        1                     _001          1  1.000000          0
#        1                     _010          1  1.000000          0
#        1                     _014          2  0.500000          1
#        1 _01_Airliner_2jetEngines          2  0.500000          1
#        1               _05_future          1  1.000000          0
#        1                      _08          2  1.000000          0
#        1                      _18          2  0.500000          0
#        1                      _37          1  0.000000          0
#        1                      _44          1  1.000000          0
#        1                   celica          2  0.000000          0
#        1                  cruiser          3  1.000000          0
#        1                 face0001          2  0.000000          0
#        1                 face0004          1  1.000000          0
#        1                 hedgehog          2  1.000000          0
#        1                junkers88          3  1.000000          0
#        1                    mig29          1  1.000000          0
#        1            raspberry_obj          2  0.000000          1
#        1                 rdbarren          2  0.500000          0
#        1               walnut_obj          2  0.000000          1
#        2          Apple_Fruit_obj          1  0.000000          0
#        2                   Beetle          1  0.000000          0
#        2               ELEPHANT_M          2  0.000000          0
#        2                  GORILLA          2  1.000000          0
#        2                Peach_obj          1  1.000000          0
#        2                 SISTER_L          2  0.500000          0
#        2                 TURTLE_L          2  1.000000          0
#        2                     _010          1  0.000000          0
#        2 _01_Airliner_2jetEngines          1  1.000000          0
#        2                     _031          1  1.000000          0
#        2                     _033          2  0.500000          0
#        2               _05_future          1  1.000000          0
#        2                      _08          2  1.000000          0
#        2                      _10          1  0.000000          1
#        2                      _11          1  1.000000          0
#        2                      _37          2  0.000000          0
#        2                      _44          1  0.000000          0
#        2                  alfa155          1  1.000000          0
#        2                   bmw325          1  1.000000          0
#        2                   celica          1  0.000000          0
#        2                      f16          1  0.000000          0
#        2                 face0001          1  1.000000          0
#        2                 face0004          1  1.000000          0
#        2                 face0005          1  1.000000          0
#        2                 face0006          2  0.500000          0
#        2                 face0008          1  1.000000          0
#        2                 hedgehog          2  0.500000          0
#        2                junkers88          1  0.000000          0
#        2                    mig29          1  0.000000          0
#        2               walnut_obj          1  0.000000          1
#        2           watermelon_obj          1  1.000000          0
#        3          Apple_Fruit_obj          2  1.000000          0
#        3                   Beetle          1  0.000000          0
#        3               ELEPHANT_M          2  1.000000          0
#        3                Peach_obj          2  0.500000          0
#        3           Strawberry_obj          1  0.000000          0
#        3                     _001          1  1.000000          0
#        3                     _010          2  0.500000          0
#        3                     _014          1  1.000000          0
#        3 _01_Airliner_2jetEngines          1  1.000000          0
#        3                     _031          1  1.000000          0
#        3               _05_future          1  0.000000          0
#        3                      _18          2  1.000000          0
#        3                      _37          1  1.000000          0
#        3                  alfa155          2  0.500000          0
#        3                     bear          3  0.333333          1
#        3                   bmw325          2  1.000000          0
#        3                   celica          1  1.000000          0
#        3                      f16          1  1.000000          0
#        3                 face0001          1  0.000000          0
#        3                 face0002          1  1.000000          0
#        3                 face0004          1  0.000000          0
#        3                 face0006          1  1.000000          0
#        3                 face0008          3  0.333333          0
#        3               motoryacht          1  0.000000          1
#        3            raspberry_obj          2  1.000000          0
#        3                  sopwith          1  1.000000          0
#        3           watermelon_obj          1  1.000000          0
#        3                       z3          1  1.000000          0
#        4          Apple_Fruit_obj          1  0.000000          0
#        4                  BAHRAIN          1  1.000000          0
#        4               ELEPHANT_M          1  1.000000          0
#        4                 MQUEEN_L          2  1.000000          0
#        4                Peach_obj          2  0.500000          0
#        4                 SISTER_L          2  1.000000          0
#        4           Strawberry_obj          1  1.000000          0
#        4                     _001          1  1.000000          0
#        4                     _010          1  1.000000          0
#        4                     _011          1  1.000000          0
#        4                     _014          2  1.000000          0
#        4                     _031          1  1.000000          0
#        4                     _033          2  0.500000          0
#        4               _05_future          1  0.000000          1
#        4                      _12          2  1.000000          0
#        4                      _37          1  1.000000          0
#        4                     bear          2  1.000000          0
#        4                     clio          3  0.666667          0
#        4                 face0004          2  1.000000          0
#        4                 face0005          1  1.000000          0
#        4                 face0008          1  1.000000          0
#        4            raspberry_obj          2  0.500000          0
#        4                 rdbarren          1  1.000000          0
#        4                  sopwith          1  1.000000          0
#        4               walnut_obj          2  1.000000          0
#        4           watermelon_obj          3  0.666667          0
#        5          Apple_Fruit_obj          1  1.000000          0
#        5                  BAHRAIN          2  1.000000          0
#        5                   Beetle          2  1.000000          0
#        5               ELEPHANT_M          1  1.000000          0
#        5                  GORILLA          1  1.000000          0
#        5                Peach_obj          2  1.000000          0
#        5                     _001          2  0.500000          0
#        5                     _010          1  1.000000          0
#        5                     _031          1  0.000000          0
#        5               _05_future          2  1.000000          0
#        5                      _11          2  0.500000          0
#        5                      _37          2  0.500000          0
#        5                      _44          2  0.500000          0
#        5                     bear          1  1.000000          0
#        5                    blCow          1  1.000000          0
#        5                   bmw325          2  1.000000          0
#        5                 face0004          1  1.000000          0
#        5                 face0005          1  0.000000          0
#        5                 face0006          1  1.000000          0
#        5                 face0008          1  1.000000          0
#        5                 hedgehog          1  1.000000          0
#        5                junkers88          1  0.000000          0
#        5                    mig29          1  0.000000          0
#        5            raspberry_obj          2  1.000000          0
#        5               walnut_obj          1  0.000000          0
#        5           watermelon_obj          3  0.333333          0
#        5                       z3          2  1.000000          0
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A16MEV9DI9VMAW/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A16MEV9DI9VMAW/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A16MEV9DI9VMAW/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A16MEV9DI9VMAW/session_summary.csv
# Saved per-session/pos_1b stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A16MEV9DI9VMAW/session_pos_1b_accuracy.csv
# Saved per-session/obj stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A16MEV9DI9VMAW/session_obj_accuracy.csv
#
# === Analyzing A1JST8K4QOV57L performance on (interdms_position_identity) ===
# Warning: #trial starts in log (200) != #rows in condition file (100). Using the minimum of the two.
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 0.00%
# Overall (per-frame) accuracy:      0.00%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20             0.0             0.0         40
#        2        20             0.0             0.0         40
#        3        20             0.0             0.0         40
#        4        20             0.0             0.0         40
#        5        20             0.0             0.0         40
#
# Per-pos_1b accuracy per session:
#  session  pos_1b  n_samples  accuracy  n_missing
#        1       1          3       0.0          3
#        1       2          3       0.0          3
#        1       3          4       0.0          4
#        1       4          1       0.0          1
#        1       5         19       0.0         19
#        1       6          2       0.0          2
#        1       7          1       0.0          1
#        1       8          5       0.0          5
#        1       9          2       0.0          2
#        2       1          1       0.0          1
#        2       2          2       0.0          2
#        2       3          4       0.0          4
#        2       4          1       0.0          1
#        2       5         19       0.0         19
#        2       6          1       0.0          1
#        2       7          6       0.0          6
#        2       8          4       0.0          4
#        2       9          2       0.0          2
#        3       1          2       0.0          2
#        3       2          1       0.0          1
#        3       3          5       0.0          5
#        3       4          4       0.0          4
#        3       5         15       0.0         15
#        3       6          5       0.0          5
#        3       7          5       0.0          5
#        3       8          2       0.0          2
#        3       9          1       0.0          1
#        4       1          3       0.0          3
#        4       2          1       0.0          1
#        4       3          3       0.0          3
#        4       4          7       0.0          7
#        4       5         15       0.0         15
#        4       6          3       0.0          3
#        4       7          5       0.0          5
#        4       8          2       0.0          2
#        4       9          1       0.0          1
#        5       1          1       0.0          1
#        5       2          1       0.0          1
#        5       3          3       0.0          3
#        5       4          1       0.0          1
#        5       5         24       0.0         24
#        5       6          4       0.0          4
#        5       7          3       0.0          3
#        5       8          1       0.0          1
#        5       9          2       0.0          2
#
# Per-obj accuracy per session:
#  session                      obj  n_samples  accuracy  n_missing
#        1          Apple_Fruit_obj          2       0.0          2
#        1                   Beetle          1       0.0          1
#        1                  GORILLA          1       0.0          1
#        1                 MQUEEN_L          1       0.0          1
#        1           Strawberry_obj          1       0.0          1
#        1                 TURTLE_L          1       0.0          1
#        1                     _001          1       0.0          1
#        1                     _010          1       0.0          1
#        1                     _014          2       0.0          2
#        1 _01_Airliner_2jetEngines          2       0.0          2
#        1               _05_future          1       0.0          1
#        1                      _08          2       0.0          2
#        1                      _18          2       0.0          2
#        1                      _37          1       0.0          1
#        1                      _44          1       0.0          1
#        1                   celica          2       0.0          2
#        1                  cruiser          3       0.0          3
#        1                 face0001          2       0.0          2
#        1                 face0004          1       0.0          1
#        1                 hedgehog          2       0.0          2
#        1                junkers88          3       0.0          3
#        1                    mig29          1       0.0          1
#        1            raspberry_obj          2       0.0          2
#        1                 rdbarren          2       0.0          2
#        1               walnut_obj          2       0.0          2
#        2          Apple_Fruit_obj          1       0.0          1
#        2                   Beetle          1       0.0          1
#        2               ELEPHANT_M          2       0.0          2
#        2                  GORILLA          2       0.0          2
#        2                Peach_obj          1       0.0          1
#        2                 SISTER_L          2       0.0          2
#        2                 TURTLE_L          2       0.0          2
#        2                     _010          1       0.0          1
#        2 _01_Airliner_2jetEngines          1       0.0          1
#        2                     _031          1       0.0          1
#        2                     _033          2       0.0          2
#        2               _05_future          1       0.0          1
#        2                      _08          2       0.0          2
#        2                      _10          1       0.0          1
#        2                      _11          1       0.0          1
#        2                      _37          2       0.0          2
#        2                      _44          1       0.0          1
#        2                  alfa155          1       0.0          1
#        2                   bmw325          1       0.0          1
#        2                   celica          1       0.0          1
#        2                      f16          1       0.0          1
#        2                 face0001          1       0.0          1
#        2                 face0004          1       0.0          1
#        2                 face0005          1       0.0          1
#        2                 face0006          2       0.0          2
#        2                 face0008          1       0.0          1
#        2                 hedgehog          2       0.0          2
#        2                junkers88          1       0.0          1
#        2                    mig29          1       0.0          1
#        2               walnut_obj          1       0.0          1
#        2           watermelon_obj          1       0.0          1
#        3          Apple_Fruit_obj          2       0.0          2
#        3                   Beetle          1       0.0          1
#        3               ELEPHANT_M          2       0.0          2
#        3                Peach_obj          2       0.0          2
#        3           Strawberry_obj          1       0.0          1
#        3                     _001          1       0.0          1
#        3                     _010          2       0.0          2
#        3                     _014          1       0.0          1
#        3 _01_Airliner_2jetEngines          1       0.0          1
#        3                     _031          1       0.0          1
#        3               _05_future          1       0.0          1
#        3                      _18          2       0.0          2
#        3                      _37          1       0.0          1
#        3                  alfa155          2       0.0          2
#        3                     bear          3       0.0          3
#        3                   bmw325          2       0.0          2
#        3                   celica          1       0.0          1
#        3                      f16          1       0.0          1
#        3                 face0001          1       0.0          1
#        3                 face0002          1       0.0          1
#        3                 face0004          1       0.0          1
#        3                 face0006          1       0.0          1
#        3                 face0008          3       0.0          3
#        3               motoryacht          1       0.0          1
#        3            raspberry_obj          2       0.0          2
#        3                  sopwith          1       0.0          1
#        3           watermelon_obj          1       0.0          1
#        3                       z3          1       0.0          1
#        4          Apple_Fruit_obj          1       0.0          1
#        4                  BAHRAIN          1       0.0          1
#        4               ELEPHANT_M          1       0.0          1
#        4                 MQUEEN_L          2       0.0          2
#        4                Peach_obj          2       0.0          2
#        4                 SISTER_L          2       0.0          2
#        4           Strawberry_obj          1       0.0          1
#        4                     _001          1       0.0          1
#        4                     _010          1       0.0          1
#        4                     _011          1       0.0          1
#        4                     _014          2       0.0          2
#        4                     _031          1       0.0          1
#        4                     _033          2       0.0          2
#        4               _05_future          1       0.0          1
#        4                      _12          2       0.0          2
#        4                      _37          1       0.0          1
#        4                     bear          2       0.0          2
#        4                     clio          3       0.0          3
#        4                 face0004          2       0.0          2
#        4                 face0005          1       0.0          1
#        4                 face0008          1       0.0          1
#        4            raspberry_obj          2       0.0          2
#        4                 rdbarren          1       0.0          1
#        4                  sopwith          1       0.0          1
#        4               walnut_obj          2       0.0          2
#        4           watermelon_obj          3       0.0          3
#        5          Apple_Fruit_obj          1       0.0          1
#        5                  BAHRAIN          2       0.0          2
#        5                   Beetle          2       0.0          2
#        5               ELEPHANT_M          1       0.0          1
#        5                  GORILLA          1       0.0          1
#        5                Peach_obj          2       0.0          2
#        5                     _001          2       0.0          2
#        5                     _010          1       0.0          1
#        5                     _031          1       0.0          1
#        5               _05_future          2       0.0          2
#        5                      _11          2       0.0          2
#        5                      _37          2       0.0          2
#        5                      _44          2       0.0          2
#        5                     bear          1       0.0          1
#        5                    blCow          1       0.0          1
#        5                   bmw325          2       0.0          2
#        5                 face0004          1       0.0          1
#        5                 face0005          1       0.0          1
#        5                 face0006          1       0.0          1
#        5                 face0008          1       0.0          1
#        5                 hedgehog          1       0.0          1
#        5                junkers88          1       0.0          1
#        5                    mig29          1       0.0          1
#        5            raspberry_obj          2       0.0          2
#        5               walnut_obj          1       0.0          1
#        5           watermelon_obj          3       0.0          3
#        5                       z3          2       0.0          2
#
# Column for RT not found or empty; RT distribution plot not generated.
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1JST8K4QOV57L/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1JST8K4QOV57L/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1JST8K4QOV57L/session_summary.csv
# Saved per-session/pos_1b stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1JST8K4QOV57L/session_pos_1b_accuracy.csv
# Saved per-session/obj stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1JST8K4QOV57L/session_obj_accuracy.csv
#
# === Analyzing A1JWRIHQLAMP6N performance on (interdms_position_identity) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 52.50%
# Overall (per-frame) accuracy:      52.50%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20           0.650           0.650          1
#        2        20           0.600           0.600          1
#        3        20           0.500           0.500          6
#        4        20           0.350           0.350          4
#        5        20           0.525           0.525          0
#
# Per-pos_1b accuracy per session:
#  session  pos_1b  n_samples  accuracy  n_missing
#        1       1          3  1.000000          0
#        1       2          3  0.666667          0
#        1       3          4  0.500000          0
#        1       4          1  1.000000          0
#        1       5         19  0.684211          1
#        1       6          2  1.000000          0
#        1       7          1  0.000000          0
#        1       8          5  0.200000          0
#        1       9          2  1.000000          0
#        2       1          1  1.000000          0
#        2       2          2  0.500000          1
#        2       3          4  1.000000          0
#        2       4          1  0.000000          0
#        2       5         19  0.473684          0
#        2       6          1  1.000000          0
#        2       7          6  0.666667          0
#        2       8          4  0.750000          0
#        2       9          2  0.500000          0
#        3       1          2  1.000000          0
#        3       2          1  1.000000          0
#        3       3          5  0.600000          1
#        3       4          4  0.750000          0
#        3       5         15  0.400000          2
#        3       6          5  0.400000          2
#        3       7          5  0.600000          0
#        3       8          2  0.000000          0
#        3       9          1  0.000000          1
#        4       1          3  0.333333          1
#        4       2          1  0.000000          0
#        4       3          3  0.666667          1
#        4       4          7  0.142857          0
#        4       5         15  0.400000          1
#        4       6          3  0.000000          1
#        4       7          5  0.200000          0
#        4       8          2  1.000000          0
#        4       9          1  1.000000          0
#        5       1          1  1.000000          0
#        5       2          1  1.000000          0
#        5       3          3  1.000000          0
#        5       4          1  1.000000          0
#        5       5         24  0.375000          0
#        5       6          4  0.500000          0
#        5       7          3  0.666667          0
#        5       8          1  1.000000          0
#        5       9          2  0.500000          0
#
# Per-obj accuracy per session:
#  session                      obj  n_samples  accuracy  n_missing
#        1          Apple_Fruit_obj          2  0.000000          0
#        1                   Beetle          1  1.000000          0
#        1                  GORILLA          1  1.000000          0
#        1                 MQUEEN_L          1  1.000000          0
#        1           Strawberry_obj          1  1.000000          0
#        1                 TURTLE_L          1  0.000000          0
#        1                     _001          1  1.000000          0
#        1                     _010          1  0.000000          0
#        1                     _014          2  1.000000          0
#        1 _01_Airliner_2jetEngines          2  0.000000          0
#        1               _05_future          1  1.000000          0
#        1                      _08          2  0.000000          1
#        1                      _18          2  1.000000          0
#        1                      _37          1  1.000000          0
#        1                      _44          1  1.000000          0
#        1                   celica          2  1.000000          0
#        1                  cruiser          3  0.666667          0
#        1                 face0001          2  0.500000          0
#        1                 face0004          1  1.000000          0
#        1                 hedgehog          2  0.500000          0
#        1                junkers88          3  1.000000          0
#        1                    mig29          1  1.000000          0
#        1            raspberry_obj          2  0.000000          0
#        1                 rdbarren          2  0.500000          0
#        1               walnut_obj          2  1.000000          0
#        2          Apple_Fruit_obj          1  1.000000          0
#        2                   Beetle          1  0.000000          0
#        2               ELEPHANT_M          2  0.500000          0
#        2                  GORILLA          2  0.500000          0
#        2                Peach_obj          1  0.000000          0
#        2                 SISTER_L          2  0.500000          0
#        2                 TURTLE_L          2  1.000000          0
#        2                     _010          1  1.000000          0
#        2 _01_Airliner_2jetEngines          1  0.000000          0
#        2                     _031          1  1.000000          0
#        2                     _033          2  0.500000          0
#        2               _05_future          1  0.000000          0
#        2                      _08          2  1.000000          0
#        2                      _10          1  0.000000          0
#        2                      _11          1  1.000000          0
#        2                      _37          2  0.000000          0
#        2                      _44          1  1.000000          0
#        2                  alfa155          1  1.000000          0
#        2                   bmw325          1  1.000000          0
#        2                   celica          1  0.000000          0
#        2                      f16          1  1.000000          0
#        2                 face0001          1  1.000000          0
#        2                 face0004          1  1.000000          0
#        2                 face0005          1  1.000000          0
#        2                 face0006          2  1.000000          0
#        2                 face0008          1  1.000000          0
#        2                 hedgehog          2  0.500000          1
#        2                junkers88          1  0.000000          0
#        2                    mig29          1  0.000000          0
#        2               walnut_obj          1  1.000000          0
#        2           watermelon_obj          1  0.000000          0
#        3          Apple_Fruit_obj          2  0.500000          0
#        3                   Beetle          1  1.000000          0
#        3               ELEPHANT_M          2  0.000000          0
#        3                Peach_obj          2  0.500000          1
#        3           Strawberry_obj          1  0.000000          0
#        3                     _001          1  0.000000          0
#        3                     _010          2  0.000000          0
#        3                     _014          1  1.000000          0
#        3 _01_Airliner_2jetEngines          1  1.000000          0
#        3                     _031          1  1.000000          0
#        3               _05_future          1  0.000000          1
#        3                      _18          2  1.000000          0
#        3                      _37          1  1.000000          0
#        3                  alfa155          2  0.500000          1
#        3                     bear          3  0.666667          0
#        3                   bmw325          2  0.500000          0
#        3                   celica          1  0.000000          1
#        3                      f16          1  1.000000          0
#        3                 face0001          1  0.000000          0
#        3                 face0002          1  0.000000          0
#        3                 face0004          1  0.000000          0
#        3                 face0006          1  1.000000          0
#        3                 face0008          3  0.000000          2
#        3               motoryacht          1  1.000000          0
#        3            raspberry_obj          2  0.500000          0
#        3                  sopwith          1  1.000000          0
#        3           watermelon_obj          1  1.000000          0
#        3                       z3          1  1.000000          0
#        4          Apple_Fruit_obj          1  0.000000          0
#        4                  BAHRAIN          1  0.000000          0
#        4               ELEPHANT_M          1  1.000000          0
#        4                 MQUEEN_L          2  1.000000          0
#        4                Peach_obj          2  0.500000          0
#        4                 SISTER_L          2  0.500000          0
#        4           Strawberry_obj          1  1.000000          0
#        4                     _001          1  0.000000          0
#        4                     _010          1  1.000000          0
#        4                     _011          1  1.000000          0
#        4                     _014          2  0.000000          2
#        4                     _031          1  0.000000          0
#        4                     _033          2  1.000000          0
#        4               _05_future          1  1.000000          0
#        4                      _12          2  0.000000          0
#        4                      _37          1  1.000000          0
#        4                     bear          2  0.000000          0
#        4                     clio          3  0.333333          0
#        4                 face0004          2  0.000000          1
#        4                 face0005          1  0.000000          0
#        4                 face0008          1  0.000000          0
#        4            raspberry_obj          2  0.500000          0
#        4                 rdbarren          1  0.000000          1
#        4                  sopwith          1  0.000000          0
#        4               walnut_obj          2  0.000000          0
#        4           watermelon_obj          3  0.000000          0
#        5          Apple_Fruit_obj          1  1.000000          0
#        5                  BAHRAIN          2  0.500000          0
#        5                   Beetle          2  0.000000          0
#        5               ELEPHANT_M          1  1.000000          0
#        5                  GORILLA          1  1.000000          0
#        5                Peach_obj          2  0.500000          0
#        5                     _001          2  0.500000          0
#        5                     _010          1  1.000000          0
#        5                     _031          1  1.000000          0
#        5               _05_future          2  0.000000          0
#        5                      _11          2  0.000000          0
#        5                      _37          2  1.000000          0
#        5                      _44          2  1.000000          0
#        5                     bear          1  1.000000          0
#        5                    blCow          1  0.000000          0
#        5                   bmw325          2  0.500000          0
#        5                 face0004          1  1.000000          0
#        5                 face0005          1  1.000000          0
#        5                 face0006          1  1.000000          0
#        5                 face0008          1  0.000000          0
#        5                 hedgehog          1  1.000000          0
#        5                junkers88          1  0.000000          0
#        5                    mig29          1  0.000000          0
#        5            raspberry_obj          2  0.500000          0
#        5               walnut_obj          1  0.000000          0
#        5           watermelon_obj          3  0.000000          0
#        5                       z3          2  1.000000          0
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1JWRIHQLAMP6N/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1JWRIHQLAMP6N/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1JWRIHQLAMP6N/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1JWRIHQLAMP6N/session_summary.csv
# Saved per-session/pos_1b stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1JWRIHQLAMP6N/session_pos_1b_accuracy.csv
# Saved per-session/obj stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1JWRIHQLAMP6N/session_obj_accuracy.csv
#
# === Analyzing A1NZ3TZGHPTS62 performance on (interdms_position_identity) ===
# Warning: #trial starts in log (200) != #rows in condition file (100). Using the minimum of the two.
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 4.50%
# Overall (per-frame) accuracy:      4.50%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20           0.000           0.000         40
#        2        20           0.000           0.000         40
#        3        20           0.000           0.000         40
#        4        20           0.025           0.025         37
#        5        20           0.200           0.200         25
#
# Per-pos_1b accuracy per session:
#  session  pos_1b  n_samples  accuracy  n_missing
#        1       1          3  0.000000          3
#        1       2          3  0.000000          3
#        1       3          4  0.000000          4
#        1       4          1  0.000000          1
#        1       5         19  0.000000         19
#        1       6          2  0.000000          2
#        1       7          1  0.000000          1
#        1       8          5  0.000000          5
#        1       9          2  0.000000          2
#        2       1          1  0.000000          1
#        2       2          2  0.000000          2
#        2       3          4  0.000000          4
#        2       4          1  0.000000          1
#        2       5         19  0.000000         19
#        2       6          1  0.000000          1
#        2       7          6  0.000000          6
#        2       8          4  0.000000          4
#        2       9          2  0.000000          2
#        3       1          2  0.000000          2
#        3       2          1  0.000000          1
#        3       3          5  0.000000          5
#        3       4          4  0.000000          4
#        3       5         15  0.000000         15
#        3       6          5  0.000000          5
#        3       7          5  0.000000          5
#        3       8          2  0.000000          2
#        3       9          1  0.000000          1
#        4       1          3  0.333333          1
#        4       2          1  0.000000          1
#        4       3          3  0.000000          3
#        4       4          7  0.000000          7
#        4       5         15  0.000000         14
#        4       6          3  0.000000          3
#        4       7          5  0.000000          5
#        4       8          2  0.000000          2
#        4       9          1  0.000000          1
#        5       1          1  1.000000          0
#        5       2          1  0.000000          1
#        5       3          3  0.333333          1
#        5       4          1  0.000000          1
#        5       5         24  0.166667         16
#        5       6          4  0.250000          3
#        5       7          3  0.000000          3
#        5       8          1  0.000000          0
#        5       9          2  0.500000          0
#
# Per-obj accuracy per session:
#  session                      obj  n_samples  accuracy  n_missing
#        1          Apple_Fruit_obj          2       0.0          2
#        1                   Beetle          1       0.0          1
#        1                  GORILLA          1       0.0          1
#        1                 MQUEEN_L          1       0.0          1
#        1           Strawberry_obj          1       0.0          1
#        1                 TURTLE_L          1       0.0          1
#        1                     _001          1       0.0          1
#        1                     _010          1       0.0          1
#        1                     _014          2       0.0          2
#        1 _01_Airliner_2jetEngines          2       0.0          2
#        1               _05_future          1       0.0          1
#        1                      _08          2       0.0          2
#        1                      _18          2       0.0          2
#        1                      _37          1       0.0          1
#        1                      _44          1       0.0          1
#        1                   celica          2       0.0          2
#        1                  cruiser          3       0.0          3
#        1                 face0001          2       0.0          2
#        1                 face0004          1       0.0          1
#        1                 hedgehog          2       0.0          2
#        1                junkers88          3       0.0          3
#        1                    mig29          1       0.0          1
#        1            raspberry_obj          2       0.0          2
#        1                 rdbarren          2       0.0          2
#        1               walnut_obj          2       0.0          2
#        2          Apple_Fruit_obj          1       0.0          1
#        2                   Beetle          1       0.0          1
#        2               ELEPHANT_M          2       0.0          2
#        2                  GORILLA          2       0.0          2
#        2                Peach_obj          1       0.0          1
#        2                 SISTER_L          2       0.0          2
#        2                 TURTLE_L          2       0.0          2
#        2                     _010          1       0.0          1
#        2 _01_Airliner_2jetEngines          1       0.0          1
#        2                     _031          1       0.0          1
#        2                     _033          2       0.0          2
#        2               _05_future          1       0.0          1
#        2                      _08          2       0.0          2
#        2                      _10          1       0.0          1
#        2                      _11          1       0.0          1
#        2                      _37          2       0.0          2
#        2                      _44          1       0.0          1
#        2                  alfa155          1       0.0          1
#        2                   bmw325          1       0.0          1
#        2                   celica          1       0.0          1
#        2                      f16          1       0.0          1
#        2                 face0001          1       0.0          1
#        2                 face0004          1       0.0          1
#        2                 face0005          1       0.0          1
#        2                 face0006          2       0.0          2
#        2                 face0008          1       0.0          1
#        2                 hedgehog          2       0.0          2
#        2                junkers88          1       0.0          1
#        2                    mig29          1       0.0          1
#        2               walnut_obj          1       0.0          1
#        2           watermelon_obj          1       0.0          1
#        3          Apple_Fruit_obj          2       0.0          2
#        3                   Beetle          1       0.0          1
#        3               ELEPHANT_M          2       0.0          2
#        3                Peach_obj          2       0.0          2
#        3           Strawberry_obj          1       0.0          1
#        3                     _001          1       0.0          1
#        3                     _010          2       0.0          2
#        3                     _014          1       0.0          1
#        3 _01_Airliner_2jetEngines          1       0.0          1
# ...
#        4                     clio          3  0.666667          0
#        4                 face0004          2  1.000000          0
#        4                 face0005          1  1.000000          0
#        4                 face0008          1  1.000000          0
#        4            raspberry_obj          2  0.500000          0
#        4                 rdbarren          1  1.000000          0
#        4                  sopwith          1  1.000000          0
#        4               walnut_obj          2  1.000000          0
#        4           watermelon_obj          3  1.000000          0
#        5          Apple_Fruit_obj          1  1.000000          0
#        5                  BAHRAIN          2  0.500000          0
#        5                   Beetle          2  1.000000          0
#        5               ELEPHANT_M          1  1.000000          0
#        5                  GORILLA          1  1.000000          0
#        5                Peach_obj          2  0.500000          0
#        5                     _001          2  0.000000          0
#        5                     _010          1  1.000000          0
#        5                     _031          1  0.000000          0
#        5               _05_future          2  1.000000          0
#        5                      _11          2  1.000000          0
#        5                      _37          2  0.500000          0
#        5                      _44          2  0.500000          0
#        5                     bear          1  1.000000          0
#        5                    blCow          1  1.000000          0
#        5                   bmw325          2  1.000000          0
#        5                 face0004          1  1.000000          0
#        5                 face0005          1  1.000000          0
#        5                 face0006          1  1.000000          0
#        5                 face0008          1  1.000000          0
#        5                 hedgehog          1  1.000000          0
#        5                junkers88          1  0.000000          0
#        5                    mig29          1  0.000000          0
#        5            raspberry_obj          2  0.500000          0
#        5               walnut_obj          1  0.000000          0
#        5           watermelon_obj          3  0.666667          0
#        5                       z3          2  1.000000          0
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1Z0G5SV4PZDUN/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1Z0G5SV4PZDUN/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1Z0G5SV4PZDUN/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1Z0G5SV4PZDUN/session_summary.csv
# Saved per-session/pos_1b stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1Z0G5SV4PZDUN/session_pos_1b_accuracy.csv
# Saved per-session/obj stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1Z0G5SV4PZDUN/session_obj_accuracy.csv
#
# === Analyzing AP8HKHQ3GP91K performance on (interdms_position_identity) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 47.50%
# Overall (per-frame) accuracy:      47.50%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20           0.425           0.425          2
#        2        20           0.525           0.525          1
#        3        20           0.425           0.425          4
#        4        20           0.650           0.650          2
#        5        20           0.350           0.350          8
#
# Per-pos_1b accuracy per session:
#  session  pos_1b  n_samples  accuracy  n_missing
#        1       1          3  1.000000          0
#        1       2          3  0.000000          0
#        1       3          4  0.500000          0
#        1       4          1  0.000000          1
#        1       5         19  0.473684          1
#        1       6          2  0.500000          0
#        1       7          1  0.000000          0
#        1       8          5  0.200000          0
#        1       9          2  0.500000          0
#        2       1          1  1.000000          0
#        2       2          2  0.500000          0
#        2       3          4  1.000000          0
#        2       4          1  0.000000          0
#        2       5         19  0.421053          0
#        2       6          1  0.000000          0
#        2       7          6  0.666667          1
#        2       8          4  0.500000          0
#        2       9          2  0.500000          0
#        3       1          2  0.500000          0
#        3       2          1  0.000000          0
#        3       3          5  0.400000          0
#        3       4          4  0.000000          0
#        3       5         15  0.466667          1
#        3       6          5  0.600000          1
#        3       7          5  0.400000          2
#        3       8          2  0.500000          0
#        3       9          1  1.000000          0
#        4       1          3  0.333333          0
#        4       2          1  1.000000          0
#        4       3          3  1.000000          0
#        4       4          7  0.571429          2
#        4       5         15  0.666667          0
#        4       6          3  0.333333          0
#        4       7          5  0.800000          0
#        4       8          2  1.000000          0
#        4       9          1  0.000000          0
#        5       1          1  0.000000          0
#        5       2          1  0.000000          1
#        5       3          3  0.333333          1
#        5       4          1  0.000000          0
#        5       5         24  0.333333          5
#        5       6          4  0.000000          1
#        5       7          3  0.666667          0
#        5       8          1  1.000000          0
#        5       9          2  1.000000          0
#
# Per-obj accuracy per session:
#  session                      obj  n_samples  accuracy  n_missing
#        1          Apple_Fruit_obj          2  0.000000          0
#        1                   Beetle          1  1.000000          0
#        1                  GORILLA          1  0.000000          0
#        1                 MQUEEN_L          1  0.000000          1
#        1           Strawberry_obj          1  1.000000          0
#        1                 TURTLE_L          1  0.000000          0
#        1                     _001          1  0.000000          0
#        1                     _010          1  0.000000          0
#        1                     _014          2  1.000000          0
#        1 _01_Airliner_2jetEngines          2  1.000000          0
#        1               _05_future          1  1.000000          0
#        1                      _08          2  0.500000          0
#        1                      _18          2  0.500000          0
#        1                      _37          1  0.000000          0
#        1                      _44          1  1.000000          0
#        1                   celica          2  0.000000          0
#        1                  cruiser          3  0.333333          0
#        1                 face0001          2  0.500000          0
#        1                 face0004          1  0.000000          0
#        1                 hedgehog          2  0.500000          0
#        1                junkers88          3  0.666667          0
#        1                    mig29          1  1.000000          0
#        1            raspberry_obj          2  0.000000          0
#        1                 rdbarren          2  0.500000          0
#        1               walnut_obj          2  0.000000          1
#        2          Apple_Fruit_obj          1  1.000000          0
#        2                   Beetle          1  1.000000          0
#        2               ELEPHANT_M          2  0.000000          0
#        2                  GORILLA          2  0.000000          0
#        2                Peach_obj          1  0.000000          0
#        2                 SISTER_L          2  0.500000          0
#        2                 TURTLE_L          2  1.000000          0
#        2                     _010          1  0.000000          0
#        2 _01_Airliner_2jetEngines          1  1.000000          0
#        2                     _031          1  1.000000          0
#        2                     _033          2  0.000000          0
#        2               _05_future          1  1.000000          0
#        2                      _08          2  0.500000          0
#        2                      _10          1  1.000000          0
#        2                      _11          1  1.000000          0
#        2                      _37          2  0.500000          0
#        2                      _44          1  0.000000          0
#        2                  alfa155          1  1.000000          0
#        2                   bmw325          1  1.000000          0
#        2                   celica          1  0.000000          0
#        2                      f16          1  1.000000          0
#        2                 face0001          1  1.000000          0
#        2                 face0004          1  1.000000          0
#        2                 face0005          1  1.000000          0
#        2                 face0006          2  0.500000          1
#        2                 face0008          1  0.000000          0
#        2                 hedgehog          2  0.500000          0
#        2                junkers88          1  0.000000          0
#        2                    mig29          1  0.000000          0
#        2               walnut_obj          1  0.000000          0
#        2           watermelon_obj          1  1.000000          0
#        3          Apple_Fruit_obj          2  0.000000          0
#        3                   Beetle          1  1.000000          0
#        3               ELEPHANT_M          2  0.000000          0
#        3                Peach_obj          2  0.500000          0
#        3           Strawberry_obj          1  0.000000          0
#        3                     _001          1  0.000000          0
#        3                     _010          2  0.500000          1
#        3                     _014          1  0.000000          0
#        3 _01_Airliner_2jetEngines          1  0.000000          0
#        3                     _031          1  1.000000          0
#        3               _05_future          1  1.000000          0
#        3                      _18          2  0.000000          0
#        3                      _37          1  1.000000          0
#        3                  alfa155          2  0.500000          0
#        3                     bear          3  0.333333          0
#        3                   bmw325          2  0.500000          1
#        3                   celica          1  0.000000          1
#        3                      f16          1  0.000000          0
#        3                 face0001          1  1.000000          0
#        3                 face0002          1  1.000000          0
#        3                 face0004          1  1.000000          0
#        3                 face0006          1  1.000000          0
#        3                 face0008          3  0.333333          1
#        3               motoryacht          1  1.000000          0
#        3            raspberry_obj          2  0.500000          0
#        3                  sopwith          1  0.000000          0
#        3           watermelon_obj          1  0.000000          0
#        3                       z3          1  1.000000          0
#        4          Apple_Fruit_obj          1  1.000000          0
#        4                  BAHRAIN          1  1.000000          0
#        4               ELEPHANT_M          1  1.000000          0
#        4                 MQUEEN_L          2  0.500000          0
#        4                Peach_obj          2  1.000000          0
#        4                 SISTER_L          2  1.000000          0
#        4           Strawberry_obj          1  0.000000          0
#        4                     _001          1  0.000000          0
#        4                     _010          1  1.000000          0
#        4                     _011          1  1.000000          0
#        4                     _014          2  0.500000          0
#        4                     _031          1  1.000000          0
#        4                     _033          2  1.000000          0
#        4               _05_future          1  0.000000          0
#        4                      _12          2  0.500000          0
#        4                      _37          1  1.000000          0
#        4                     bear          2  1.000000          0
#        4                     clio          3  0.666667          0
#        4                 face0004          2  1.000000          0
#        4                 face0005          1  0.000000          0
#        4                 face0008          1  0.000000          0
#        4            raspberry_obj          2  1.000000          0
#        4                 rdbarren          1  1.000000          0
#        4                  sopwith          1  1.000000          0
#        4               walnut_obj          2  0.000000          0
#        4           watermelon_obj          3  0.000000          2
#        5          Apple_Fruit_obj          1  0.000000          0
#        5                  BAHRAIN          2  0.000000          0
#        5                   Beetle          2  0.500000          0
#        5               ELEPHANT_M          1  1.000000          0
#        5                  GORILLA          1  1.000000          0
#        5                Peach_obj          2  0.500000          0
#        5                     _001          2  0.000000          0
#        5                     _010          1  1.000000          0
#        5                     _031          1  0.000000          1
#        5               _05_future          2  0.500000          0
#        5                      _11          2  0.500000          0
#        5                      _37          2  0.000000          1
#        5                      _44          2  0.500000          0
#        5                     bear          1  0.000000          0
#        5                    blCow          1  1.000000          0
#        5                   bmw325          2  0.500000          1
#        5                 face0004          1  0.000000          0
#        5                 face0005          1  0.000000          0
#        5                 face0006          1  1.000000          0
#        5                 face0008          1  0.000000          0
#        5                 hedgehog          1  0.000000          1
#        5                junkers88          1  0.000000          0
#        5                    mig29          1  0.000000          0
#        5            raspberry_obj          2  0.500000          1
#        5               walnut_obj          1  0.000000          1
#        5           watermelon_obj          3  0.333333          1
#        5                       z3          2  0.500000          1
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AP8HKHQ3GP91K/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AP8HKHQ3GP91K/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AP8HKHQ3GP91K/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AP8HKHQ3GP91K/session_summary.csv
# Saved per-session/pos_1b stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AP8HKHQ3GP91K/session_pos_1b_accuracy.csv
# Saved per-session/obj stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AP8HKHQ3GP91K/session_obj_accuracy.csv
#
# ✅ Done running analysis for all available response files.
