# %%
import shutil
from functools import partial
from pathlib import Path

import pandas as pd

from utils.trial_analysis_helper import (
    TaskConfig,
    mturk_localize,
    split_by_worker_and_exp,
    analyze_accuracy, task_analysis,
)

# %%
def analyze_all_subjects(
        behavior_dir,
        trial_df,
        meta_df,
        task_config: TaskConfig,
        pattern="Responses - 1back_*.csv",
):
    """
    Iterate over all response files in `behavior_dir` matching `pattern`
    and run analyze_accuracy on each, using the provided TaskConfig.

    Each subject's outputs will be saved next to their own response file.
    """
    behavior_dir = Path(behavior_dir)
    files = sorted(behavior_dir.glob(pattern))

    if not files:
        print(f"No files matching pattern '{pattern}' found in {behavior_dir}")
        return

    print(f"Found {len(files)} files to analyze in {behavior_dir}:")
    for f in files:
        print(f"  - {f.name}")

    for f in files:
        worker = f.stem.split('_')[0]
        print(f"\n=== Analyzing {worker} performance on ({task_config.task_name}) ===")
        # Create a subdirectory for this worker
        worker_dir = behavior_dir / worker
        worker_dir.mkdir(exist_ok=True, parents=True)

        # Copy raw CSV into the worker folder
        raw_copy_path = worker_dir / f.name
        shutil.copy(f, raw_copy_path)

        behavior_df = pd.read_csv(f)
        summary_df, detail_df = analyze_accuracy(
            behaviour_df=behavior_df,
            trial_df=trial_df,
            meta_df=meta_df,
            task_config=task_config,
        )
        summary = task_analysis(
            summary_df=summary_df,
            detail_df=detail_df,
            task_config=task_config,
            output_prefix=worker_dir,
        )
    print("\n✅ Done running analysis for all available response files.")
    return

# %%
project_dir = Path.cwd().parent
resource_dir = project_dir / 'resources'
data_dir = project_dir / 'data'

one_back_config = TaskConfig(
    task_name="1back_category",

    act_cols=["act2", "act3", "act4", "act5", "act6"],
    stim_cols=["stim1", "stim2", "stim3", "stim4", "stim5", "stim6"],
    act_indices=[2, 3, 4, 5, 6],

    features=['category'],

    task_trial_csv=resource_dir / '1back_category_trials.csv',
    task_meta_csv=resource_dir / '1back_category_subset.csv',

    num_sessions=5,
    trials_per_session=20,
    frames_per_trial=6,
)
inter_config = TaskConfig(
    task_name="interdms_position_identity",

    act_cols=["act3", "act4"],
    act_indices=[3, 4],
    stim_cols=["stim1", "stim2", "stim3", "stim4"],
    features=['pos_1b', 'obj'],

    task_trial_csv=resource_dir / 'interdms_position_identity_trials.csv',
    task_meta_csv=resource_dir / 'stim_subset.csv',

    num_sessions=5,
    trials_per_session=20,
    frames_per_trial=4,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2 resource_dir = project_dir / 'resources'
#       3 data_dir = project_dir / 'data'
# ----> 5 one_back_config = TaskConfig(
#       6     task_name="1back_category",
#       7
#       8     act_cols=["act2", "act3", "act4", "act5", "act6"],
#       9     stim_cols=["stim1", "stim2", "stim3", "stim4", "stim5", "stim6"],
#      10     act_indices=[2, 3, 4, 5, 6],
#      11
#      12     features=['category'],
#      13
#      14     task_trial_csv=resource_dir / '1back_category_trials.csv',
#      15     task_meta_csv=resource_dir / '1back_category_subset.csv',
#      16
#      17     num_sessions=5,
#      18     trials_per_session=20,
#      19     frames_per_trial=6,
#      20 )
#      21 inter_config = TaskConfig(
#      22     task_name="interdms_position_identity",
#      23
#    (...)
#      34     frames_per_trial=4,
#      35 )
#
# TypeError: __init__() got an unexpected keyword argument 'num_sessions'

# %%
split_by_worker_and_exp(
    data_dir / 'responses.csv',
    data_dir,
    worker_list={
        'A1G2INV69IS9ST',
        'A204K98WHPRQPW',
        'A2GCS7CZ09CLTM',
        'A1EGBHBVA8SJZQ',
        'A26PZQAKSJGCIQ',
        'A3IDRTM133H0VQ',
        'AF0GETCJCB9SU',
        'A25BXJQG5ZF9M',
        'A2TDHNWZL5BC6E',
        'AI2DTO8YE8QCQ'
    },
    task_list=['1back_category']
)
meta_df = pd.read_csv(resource_dir / one_back_config.task_meta_csv)
meta_df['filename'] = meta_df['filename'].apply(
    partial(mturk_localize, Path('images'))
)

analyze_all_subjects(
    behavior_dir=data_dir,
    trial_df=pd.read_csv(resource_dir / one_back_config.task_trial_csv),
    meta_df=meta_df,
    task_config=one_back_config,
    pattern=f'*_{one_back_config.task_name}.csv'
)
# Out:
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2GCS7CZ09CLTM_1back_category.csv
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1EGBHBVA8SJZQ_1back_category.csv
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A26PZQAKSJGCIQ_1back_category.csv
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A25BXJQG5ZF9M_1back_category.csv
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1G2INV69IS9ST_1back_category.csv
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2TDHNWZL5BC6E_1back_category.csv
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AF0GETCJCB9SU_1back_category.csv
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A204K98WHPRQPW_1back_category.csv
# Saved 704 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AI2DTO8YE8QCQ_1back_category.csv
# Found 9 files to analyze in /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data:
#   - A1EGBHBVA8SJZQ_1back_category.csv
#   - A1G2INV69IS9ST_1back_category.csv
#   - A204K98WHPRQPW_1back_category.csv
#   - A25BXJQG5ZF9M_1back_category.csv
#   - A26PZQAKSJGCIQ_1back_category.csv
#   - A2GCS7CZ09CLTM_1back_category.csv
#   - A2TDHNWZL5BC6E_1back_category.csv
#   - AF0GETCJCB9SU_1back_category.csv
#   - AI2DTO8YE8QCQ_1back_category.csv
#
# === Analyzing A1EGBHBVA8SJZQ performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 82.40%
# Overall (per-frame) accuracy:      82.40%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.65            0.65         16
#        2        20            0.82            0.82          1
#        3        20            0.88            0.88          3
#        4        20            0.88            0.88          3
#        5        20            0.89            0.89          6
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.529412          4
#        1    Boats         14  0.785714          0
#        1     Cars         23  0.739130          5
#        1    Faces         13  0.615385          3
#        1   Fruits         18  0.611111          2
#        1   Planes         15  0.600000          2
#        2  Animals         15  0.666667          0
#        2    Boats         13  0.923077          0
#        2     Cars         21  0.904762          1
#        2    Faces         12  1.000000          0
#        2   Fruits         20  0.600000          0
#        2   Planes         19  0.894737          0
#        3  Animals          9  0.666667          0
#        3    Boats         15  0.866667          0
#        3     Cars          8  1.000000          0
#        3    Faces         21  0.857143          2
#        3   Fruits         19  0.894737          1
#        3   Planes         28  0.928571          0
#        4  Animals         25  0.680000          0
#        4    Boats          6  1.000000          0
#        4     Cars         20  0.950000          1
#        4    Faces         14  1.000000          0
#        4   Fruits         11  0.818182          2
#        4   Planes         24  0.958333          0
#        5  Animals         13  0.846154          0
#        5    Boats          8  1.000000          0
#        5     Cars         27  0.814815          3
#        5    Faces         15  0.866667          2
#        5   Fruits         18  1.000000          0
#        5   Planes         19  0.894737          1
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1EGBHBVA8SJZQ/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1EGBHBVA8SJZQ/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1EGBHBVA8SJZQ/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1EGBHBVA8SJZQ/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1EGBHBVA8SJZQ/session_category_accuracy.csv
#
# === Analyzing A1G2INV69IS9ST performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 57.40%
# Overall (per-frame) accuracy:      57.40%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.82            0.82          3
#        2        20            0.66            0.66         23
#        3        20            0.55            0.55         28
#        4        20            0.38            0.38         49
#        5        20            0.46            0.46         39
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.588235          0
#        1    Boats         14  0.928571          0
#        1     Cars         23  0.913043          1
#        1    Faces         13  0.846154          0
#        1   Fruits         18  0.888889          0
#        1   Planes         15  0.733333          2
#        2  Animals         15  0.533333          3
#        2    Boats         13  0.384615          8
#        2     Cars         21  0.666667          4
#        2    Faces         12  0.916667          1
#        2   Fruits         20  0.550000          5
#        2   Planes         19  0.894737          2
#        3  Animals          9  0.333333          4
#        3    Boats         15  0.666667          3
#        3     Cars          8  0.375000          3
#        3    Faces         21  0.571429          7
#        3   Fruits         19  0.631579          3
#        3   Planes         28  0.535714          8
#        4  Animals         25  0.360000         13
#        4    Boats          6  0.333333          3
#        4     Cars         20  0.400000          8
#        4    Faces         14  0.428571          6
#        4   Fruits         11  0.454545          5
#        4   Planes         24  0.333333         14
#        5  Animals         13  0.230769          6
#        5    Boats          8  0.375000          3
#        5     Cars         27  0.592593          8
#        5    Faces         15  0.466667          8
#        5   Fruits         18  0.500000          6
#        5   Planes         19  0.421053          8
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1G2INV69IS9ST/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1G2INV69IS9ST/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1G2INV69IS9ST/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1G2INV69IS9ST/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1G2INV69IS9ST/session_category_accuracy.csv
#
# === Analyzing A204K98WHPRQPW performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 33.40%
# Overall (per-frame) accuracy:      33.40%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.30            0.30         52
#        2        20            0.36            0.36         48
#        3        20            0.32            0.32         45
#        4        20            0.37            0.37         45
#        5        20            0.32            0.32         51
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.411765          8
#        1    Boats         14  0.357143          7
#        1     Cars         23  0.260870         12
#        1    Faces         13  0.307692          8
#        1   Fruits         18  0.333333          9
#        1   Planes         15  0.133333          8
#        2  Animals         15  0.333333          8
#        2    Boats         13  0.076923          8
#        2     Cars         21  0.428571          8
#        2    Faces         12  0.583333          5
#        2   Fruits         20  0.300000         11
#        2   Planes         19  0.421053          8
#        3  Animals          9  0.333333          4
#        3    Boats         15  0.400000          5
#        3     Cars          8  0.000000          4
#        3    Faces         21  0.428571         12
#        3   Fruits         19  0.263158          8
#        3   Planes         28  0.321429         12
#        4  Animals         25  0.400000          8
#        4    Boats          6  0.500000          2
#        4     Cars         20  0.450000          9
#        4    Faces         14  0.428571          8
#        4   Fruits         11  0.272727          6
#        4   Planes         24  0.250000         12
#        5  Animals         13  0.307692          7
#        5    Boats          8  0.500000          3
#        5     Cars         27  0.222222         15
#        5    Faces         15  0.400000          7
#        5   Fruits         18  0.222222         11
#        5   Planes         19  0.421053          8
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A204K98WHPRQPW/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A204K98WHPRQPW/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A204K98WHPRQPW/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A204K98WHPRQPW/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A204K98WHPRQPW/session_category_accuracy.csv
#
# === Analyzing A25BXJQG5ZF9M performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 0.00%
# Overall (per-frame) accuracy:      0.00%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20             0.0             0.0        100
#        2        20             0.0             0.0        100
#        3        20             0.0             0.0        100
#        4        20             0.0             0.0        100
#        5        20             0.0             0.0        100
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17       0.0         17
#        1    Boats         14       0.0         14
#        1     Cars         23       0.0         23
#        1    Faces         13       0.0         13
#        1   Fruits         18       0.0         18
#        1   Planes         15       0.0         15
#        2  Animals         15       0.0         15
#        2    Boats         13       0.0         13
#        2     Cars         21       0.0         21
#        2    Faces         12       0.0         12
#        2   Fruits         20       0.0         20
#        2   Planes         19       0.0         19
#        3  Animals          9       0.0          9
#        3    Boats         15       0.0         15
#        3     Cars          8       0.0          8
#        3    Faces         21       0.0         21
#        3   Fruits         19       0.0         19
#        3   Planes         28       0.0         28
#        4  Animals         25       0.0         25
#        4    Boats          6       0.0          6
#        4     Cars         20       0.0         20
#        4    Faces         14       0.0         14
#        4   Fruits         11       0.0         11
#        4   Planes         24       0.0         24
#        5  Animals         13       0.0         13
#        5    Boats          8       0.0          8
#        5     Cars         27       0.0         27
#        5    Faces         15       0.0         15
#        5   Fruits         18       0.0         18
#        5   Planes         19       0.0         19
#
# Column for RT not found or empty; RT distribution plot not generated.
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A25BXJQG5ZF9M/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A25BXJQG5ZF9M/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A25BXJQG5ZF9M/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A25BXJQG5ZF9M/session_category_accuracy.csv
#
# === Analyzing A26PZQAKSJGCIQ performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 50.00%
# Overall (per-frame) accuracy:      50.00%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.71            0.71         11
#        2        20            0.57            0.57         29
#        3        20            0.48            0.48         30
#        4        20            0.47            0.47         46
#        5        20            0.27            0.27         69
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.529412          2
#        1    Boats         14  0.571429          2
#        1     Cars         23  0.782609          2
#        1    Faces         13  0.769231          0
#        1   Fruits         18  0.888889          2
#        1   Planes         15  0.666667          3
#        2  Animals         15  0.333333          6
#        2    Boats         13  0.461538          5
#        2     Cars         21  0.619048          6
#        2    Faces         12  0.750000          3
#        2   Fruits         20  0.600000          4
#        2   Planes         19  0.631579          5
#        3  Animals          9  0.222222          4
#        3    Boats         15  0.533333          4
#        3     Cars          8  0.375000          3
#        3    Faces         21  0.428571          7
#        3   Fruits         19  0.631579          3
#        3   Planes         28  0.500000          9
#        4  Animals         25  0.560000          8
#        4    Boats          6  0.500000          2
#        4     Cars         20  0.350000         12
#        4    Faces         14  0.357143          7
#        4   Fruits         11  0.454545          6
#        4   Planes         24  0.541667         11
#        5  Animals         13  0.153846         10
#        5    Boats          8  0.250000          6
#        5     Cars         27  0.333333         18
#        5    Faces         15  0.200000         12
#        5   Fruits         18  0.277778         12
#        5   Planes         19  0.315789         11
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A26PZQAKSJGCIQ/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A26PZQAKSJGCIQ/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A26PZQAKSJGCIQ/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A26PZQAKSJGCIQ/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A26PZQAKSJGCIQ/session_category_accuracy.csv
#
# === Analyzing A2GCS7CZ09CLTM performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 41.80%
# Overall (per-frame) accuracy:      41.80%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.34            0.34         44
#        2        20            0.45            0.45         26
#        3        20            0.38            0.38         21
#        4        20            0.45            0.45         20
#        5        20            0.47            0.47         23
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.294118          8
#        1    Boats         14  0.142857          9
#        1     Cars         23  0.521739          7
#        1    Faces         13  0.461538          3
#        1   Fruits         18  0.222222          7
#        1   Planes         15  0.333333         10
#        2  Animals         15  0.466667          6
#        2    Boats         13  0.307692          5
#        2     Cars         21  0.476190          4
#        2    Faces         12  0.416667          2
#        2   Fruits         20  0.500000          3
#        2   Planes         19  0.473684          6
#        3  Animals          9  0.444444          1
#        3    Boats         15  0.400000          1
#        3     Cars          8  0.500000          1
#        3    Faces         21  0.285714          6
#        3   Fruits         19  0.315789          8
#        3   Planes         28  0.428571          4
#        4  Animals         25  0.480000          7
#        4    Boats          6  0.500000          1
#        4     Cars         20  0.400000          7
#        4    Faces         14  0.285714          2
#        4   Fruits         11  0.545455          0
#        4   Planes         24  0.500000          3
#        5  Animals         13  0.307692          3
#        5    Boats          8  0.125000          2
#        5     Cars         27  0.518519          7
#        5    Faces         15  0.466667          3
#        5   Fruits         18  0.777778          1
#        5   Planes         19  0.368421          7
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2GCS7CZ09CLTM/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2GCS7CZ09CLTM/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2GCS7CZ09CLTM/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2GCS7CZ09CLTM/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2GCS7CZ09CLTM/session_category_accuracy.csv
#
# === Analyzing A2TDHNWZL5BC6E performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 23.00%
# Overall (per-frame) accuracy:      23.00%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.37            0.37         21
#        2        20            0.07            0.07         88
#        3        20            0.38            0.38         21
#        4        20            0.18            0.18         71
#        5        20            0.15            0.15         72
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.529412          3
#        1    Boats         14  0.357143          2
#        1     Cars         23  0.260870          7
#        1    Faces         13  0.384615          4
#        1   Fruits         18  0.388889          2
#        1   Planes         15  0.333333          3
#        2  Animals         15  0.133333         13
#        2    Boats         13  0.076923         11
#        2     Cars         21  0.095238         17
#        2    Faces         12  0.000000         12
#        2   Fruits         20  0.050000         19
#        2   Planes         19  0.052632         16
#        3  Animals          9  0.333333          2
#        3    Boats         15  0.333333          4
#        3     Cars          8  0.625000          2
#        3    Faces         21  0.285714          3
#        3   Fruits         19  0.315789          4
#        3   Planes         28  0.464286          6
#        4  Animals         25  0.120000         19
#        4    Boats          6  0.000000          6
#        4     Cars         20  0.250000         13
#        4    Faces         14  0.071429         12
#        4   Fruits         11  0.272727          6
#        4   Planes         24  0.250000         15
#        5  Animals         13  0.153846         10
#        5    Boats          8  0.125000          7
#        5     Cars         27  0.148148         19
#        5    Faces         15  0.200000         10
#        5   Fruits         18  0.055556         16
#        5   Planes         19  0.210526         10
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2TDHNWZL5BC6E/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2TDHNWZL5BC6E/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2TDHNWZL5BC6E/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2TDHNWZL5BC6E/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2TDHNWZL5BC6E/session_category_accuracy.csv
#
# === Analyzing AF0GETCJCB9SU performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 27.20%
# Overall (per-frame) accuracy:      27.20%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.30            0.30         44
#        2        20            0.27            0.27         49
#        3        20            0.26            0.26         49
#        4        20            0.28            0.28         48
#        5        20            0.25            0.25         50
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.235294          9
#        1    Boats         14  0.500000          4
#        1     Cars         23  0.173913         10
#        1    Faces         13  0.461538          6
#        1   Fruits         18  0.277778         10
#        1   Planes         15  0.266667          5
#        2  Animals         15  0.266667          9
#        2    Boats         13  0.307692          5
#        2     Cars         21  0.190476         11
#        2    Faces         12  0.333333          6
#        2   Fruits         20  0.250000         10
#        2   Planes         19  0.315789          8
#        3  Animals          9  0.333333          5
#        3    Boats         15  0.266667          8
#        3     Cars          8  0.000000          3
#        3    Faces         21  0.142857         11
#        3   Fruits         19  0.315789          9
#        3   Planes         28  0.357143         13
#        4  Animals         25  0.280000         13
#        4    Boats          6  0.333333          3
#        4     Cars         20  0.350000          8
#        4    Faces         14  0.285714          7
#        4   Fruits         11  0.363636          4
#        4   Planes         24  0.166667         13
#        5  Animals         13  0.461538          4
#        5    Boats          8  0.250000          5
#        5     Cars         27  0.222222         13
#        5    Faces         15  0.133333          9
#        5   Fruits         18  0.166667         11
#        5   Planes         19  0.315789          8
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AF0GETCJCB9SU/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AF0GETCJCB9SU/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AF0GETCJCB9SU/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AF0GETCJCB9SU/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AF0GETCJCB9SU/session_category_accuracy.csv
#
# === Analyzing AI2DTO8YE8QCQ performance on (1back_category) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 3.20%
# Overall (per-frame) accuracy:      3.20%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.13            0.13         71
#        2        20            0.01            0.01         97
#        3        20            0.00            0.00         99
#        4        20            0.02            0.02         96
#        5        20            0.00            0.00         98
#
# Per-category accuracy per session:
#  session category  n_samples  accuracy  n_missing
#        1  Animals         17  0.058824         12
#        1    Boats         14  0.071429         12
#        1     Cars         23  0.173913         13
#        1    Faces         13  0.153846          9
#        1   Fruits         18  0.000000         16
#        1   Planes         15  0.333333          9
#        2  Animals         15  0.000000         15
#        2    Boats         13  0.000000         13
#        2     Cars         21  0.000000         21
#        2    Faces         12  0.000000         12
#        2   Fruits         20  0.050000         18
#        2   Planes         19  0.000000         18
#        3  Animals          9  0.000000          9
#        3    Boats         15  0.000000         15
#        3     Cars          8  0.000000          8
#        3    Faces         21  0.000000         20
#        3   Fruits         19  0.000000         19
#        3   Planes         28  0.000000         28
#        4  Animals         25  0.040000         24
#        4    Boats          6  0.000000          6
#        4     Cars         20  0.000000         19
#        4    Faces         14  0.000000         14
#        4   Fruits         11  0.000000         10
#        4   Planes         24  0.041667         23
#        5  Animals         13  0.000000         12
#        5    Boats          8  0.000000          8
#        5     Cars         27  0.000000         26
#        5    Faces         15  0.000000         15
#        5   Fruits         18  0.000000         18
#        5   Planes         19  0.000000         19
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AI2DTO8YE8QCQ/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AI2DTO8YE8QCQ/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AI2DTO8YE8QCQ/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AI2DTO8YE8QCQ/session_summary.csv
# Saved per-session/category stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AI2DTO8YE8QCQ/session_category_accuracy.csv
#
# ✅ Done running analysis for all available response files.

# %%
split_by_worker_and_exp(
    data_dir / 'responses.csv',
    data_dir,
    worker_list=[
        'A2MHDAPN4DVTG4',
        'ACQU0SPM3WZ5H',
        'A2X78M49ORM3L7',
        'AH7A6WY6V76KP',
        'A1LX7YK0EBOSF7',
        'A2ACGF53MHGQ1K',
        'A1NRDN6SEGOTGA',
        'A2G4TQWINTVEWZ',
        'A12JMDZR9O4MJ4',
        'A213YYZ2PSVSB4'
    ],
    task_list=['interdms_position_identity']
)
meta_df = pd.read_csv(resource_dir / inter_config.task_meta_csv)

meta_df['filename'] = meta_df['filename'].apply(
    partial(mturk_localize, Path('images'))
)

analyze_all_subjects(
    behavior_dir=data_dir,
    trial_df=pd.read_csv(resource_dir / inter_config.task_trial_csv),
    meta_df=meta_df,
    task_config=inter_config,
    pattern=f'*_{inter_config.task_name}.csv'
)
# Out:
# Saved 504 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2MHDAPN4DVTG4_interdms_position_identity.csv
# Saved 504 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2X78M49ORM3L7_interdms_position_identity.csv
# Saved 504 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2G4TQWINTVEWZ_interdms_position_identity.csv
# Saved 504 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2ACGF53MHGQ1K_interdms_position_identity.csv
# Saved 504 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1NRDN6SEGOTGA_interdms_position_identity.csv
# Saved 504 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AH7A6WY6V76KP_interdms_position_identity.csv
# Saved 504 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/ACQU0SPM3WZ5H_interdms_position_identity.csv
# Saved 504 rows to /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1LX7YK0EBOSF7_interdms_position_identity.csv
# Found 8 files to analyze in /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data:
#   - A1LX7YK0EBOSF7_interdms_position_identity.csv
#   - A1NRDN6SEGOTGA_interdms_position_identity.csv
#   - A2ACGF53MHGQ1K_interdms_position_identity.csv
#   - A2G4TQWINTVEWZ_interdms_position_identity.csv
#   - A2MHDAPN4DVTG4_interdms_position_identity.csv
#   - A2X78M49ORM3L7_interdms_position_identity.csv
#   - ACQU0SPM3WZ5H_interdms_position_identity.csv
#   - AH7A6WY6V76KP_interdms_position_identity.csv
#
# === Analyzing A1LX7YK0EBOSF7 performance on (interdms_position_identity) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 2.00%
# Overall (per-frame) accuracy:      2.00%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20             0.1             0.1         33
#        2        20             0.0             0.0         40
#        3        20             0.0             0.0         40
#        4        20             0.0             0.0         40
#        5        20             0.0             0.0         40
#
# Per-pos_1b accuracy per session:
#  session  pos_1b  n_samples  accuracy  n_missing
#        1       1          3  0.000000          3
#        1       2          3  0.000000          3
#        1       3          4  0.250000          3
#        1       4          1  0.000000          1
#        1       5         19  0.052632         17
#        1       6          2  0.500000          1
#        1       7          1  0.000000          0
#        1       8          5  0.000000          4
#        1       9          2  0.500000          1
#        2       1          1  0.000000          1
#        2       2          2  0.000000          2
#        2       3          4  0.000000          4
#        2       4          1  0.000000          1
#        2       5         19  0.000000         19
#        2       6          1  0.000000          1
#        2       7          6  0.000000          6
#        2       8          4  0.000000          4
#        2       9          2  0.000000          2
#        3       1          2  0.000000          2
#        3       2          1  0.000000          1
#        3       3          5  0.000000          5
#        3       4          4  0.000000          4
#        3       5         15  0.000000         15
#        3       6          5  0.000000          5
#        3       7          5  0.000000          5
#        3       8          2  0.000000          2
#        3       9          1  0.000000          1
#        4       1          3  0.000000          3
#        4       2          1  0.000000          1
#        4       3          3  0.000000          3
#        4       4          7  0.000000          7
#        4       5         15  0.000000         15
#        4       6          3  0.000000          3
#        4       7          5  0.000000          5
#        4       8          2  0.000000          2
#        4       9          1  0.000000          1
#        5       1          1  0.000000          1
#        5       2          1  0.000000          1
#        5       3          3  0.000000          3
#        5       4          1  0.000000          1
#        5       5         24  0.000000         24
#        5       6          4  0.000000          4
#        5       7          3  0.000000          3
#        5       8          1  0.000000          1
#        5       9          2  0.000000          2
#
# Per-obj accuracy per session:
#  session                      obj  n_samples  accuracy  n_missing
#        1          Apple_Fruit_obj          2  0.000000          2
#        1                   Beetle          1  1.000000          0
#        1                  GORILLA          1  0.000000          1
#        1                 MQUEEN_L          1  1.000000          0
#        1           Strawberry_obj          1  0.000000          1
#        1                 TURTLE_L          1  0.000000          1
#        1                     _001          1  0.000000          1
#        1                     _010          1  0.000000          0
#        1                     _014          2  0.000000          2
#        1 _01_Airliner_2jetEngines          2  0.000000          1
#        1               _05_future          1  1.000000          0
#        1                      _08          2  0.000000          2
#        1                      _18          2  0.000000          2
#        1                      _37          1  0.000000          1
#        1                      _44          1  0.000000          1
#        1                   celica          2  0.000000          2
#        1                  cruiser          3  0.000000          3
#        1                 face0001          2  0.000000          1
#        1                 face0004          1  0.000000          1
#        1                 hedgehog          2  0.000000          2
#        1                junkers88          3  0.333333          2
#        1                    mig29          1  0.000000          1
#        1            raspberry_obj          2  0.000000          2
#        1                 rdbarren          2  0.000000          2
#        1               walnut_obj          2  0.000000          2
#        2          Apple_Fruit_obj          1  0.000000          1
#        2                   Beetle          1  0.000000          1
#        2               ELEPHANT_M          2  0.000000          2
#        2                  GORILLA          2  0.000000          2
#        2                Peach_obj          1  0.000000          1
#        2                 SISTER_L          2  0.000000          2
#        2                 TURTLE_L          2  0.000000          2
#        2                     _010          1  0.000000          1
#        2 _01_Airliner_2jetEngines          1  0.000000          1
#        2                     _031          1  0.000000          1
#        2                     _033          2  0.000000          2
#        2               _05_future          1  0.000000          1
#        2                      _08          2  0.000000          2
#        2                      _10          1  0.000000          1
#        2                      _11          1  0.000000          1
#        2                      _37          2  0.000000          2
#        2                      _44          1  0.000000          1
#        2                  alfa155          1  0.000000          1
#        2                   bmw325          1  0.000000          1
#        2                   celica          1  0.000000          1
#        2                      f16          1  0.000000          1
#        2                 face0001          1  0.000000          1
#        2                 face0004          1  0.000000          1
#        2                 face0005          1  0.000000          1
#        2                 face0006          2  0.000000          2
#        2                 face0008          1  0.000000          1
#        2                 hedgehog          2  0.000000          2
#        2                junkers88          1  0.000000          1
#        2                    mig29          1  0.000000          1
#        2               walnut_obj          1  0.000000          1
#        2           watermelon_obj          1  0.000000          1
#        3          Apple_Fruit_obj          2  0.000000          2
#        3                   Beetle          1  0.000000          1
#        3               ELEPHANT_M          2  0.000000          2
#        3                Peach_obj          2  0.000000          2
#        3           Strawberry_obj          1  0.000000          1
#        3                     _001          1  0.000000          1
#        3                     _010          2  0.000000          2
#        3                     _014          1  0.000000          1
#        3 _01_Airliner_2jetEngines          1  0.000000          1
#        3                     _031          1  0.000000          1
#        3               _05_future          1  0.000000          1
#        3                      _18          2  0.000000          2
#        3                      _37          1  0.000000          1
#        3                  alfa155          2  0.000000          2
#        3                     bear          3  0.000000          3
#        3                   bmw325          2  0.000000          2
#        3                   celica          1  0.000000          1
#        3                      f16          1  0.000000          1
#        3                 face0001          1  0.000000          1
#        3                 face0002          1  0.000000          1
#        3                 face0004          1  0.000000          1
#        3                 face0006          1  0.000000          1
#        3                 face0008          3  0.000000          3
#        3               motoryacht          1  0.000000          1
#        3            raspberry_obj          2  0.000000          2
#        3                  sopwith          1  0.000000          1
#        3           watermelon_obj          1  0.000000          1
#        3                       z3          1  0.000000          1
#        4          Apple_Fruit_obj          1  0.000000          1
#        4                  BAHRAIN          1  0.000000          1
#        4               ELEPHANT_M          1  0.000000          1
#        4                 MQUEEN_L          2  0.000000          2
#        4                Peach_obj          2  0.000000          2
#        4                 SISTER_L          2  0.000000          2
#        4           Strawberry_obj          1  0.000000          1
#        4                     _001          1  0.000000          1
#        4                     _010          1  0.000000          1
#        4                     _011          1  0.000000          1
#        4                     _014          2  0.000000          2
#        4                     _031          1  0.000000          1
#        4                     _033          2  0.000000          2
#        4               _05_future          1  0.000000          1
#        4                      _12          2  0.000000          2
#        4                      _37          1  0.000000          1
#        4                     bear          2  0.000000          2
#        4                     clio          3  0.000000          3
#        4                 face0004          2  0.000000          2
#        4                 face0005          1  0.000000          1
#        4                 face0008          1  0.000000          1
#        4            raspberry_obj          2  0.000000          2
#        4                 rdbarren          1  0.000000          1
#        4                  sopwith          1  0.000000          1
#        4               walnut_obj          2  0.000000          2
#        4           watermelon_obj          3  0.000000          3
#        5          Apple_Fruit_obj          1  0.000000          1
#        5                  BAHRAIN          2  0.000000          2
#        5                   Beetle          2  0.000000          2
#        5               ELEPHANT_M          1  0.000000          1
#        5                  GORILLA          1  0.000000          1
#        5                Peach_obj          2  0.000000          2
#        5                     _001          2  0.000000          2
#        5                     _010          1  0.000000          1
#        5                     _031          1  0.000000          1
#        5               _05_future          2  0.000000          2
#        5                      _11          2  0.000000          2
#        5                      _37          2  0.000000          2
#        5                      _44          2  0.000000          2
#        5                     bear          1  0.000000          1
#        5                    blCow          1  0.000000          1
#        5                   bmw325          2  0.000000          2
#        5                 face0004          1  0.000000          1
#        5                 face0005          1  0.000000          1
#        5                 face0006          1  0.000000          1
#        5                 face0008          1  0.000000          1
#        5                 hedgehog          1  0.000000          1
#        5                junkers88          1  0.000000          1
#        5                    mig29          1  0.000000          1
#        5            raspberry_obj          2  0.000000          2
#        5               walnut_obj          1  0.000000          1
#        5           watermelon_obj          3  0.000000          3
#        5                       z3          2  0.000000          2
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1LX7YK0EBOSF7/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1LX7YK0EBOSF7/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1LX7YK0EBOSF7/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1LX7YK0EBOSF7/session_summary.csv
# Saved per-session/pos_1b stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1LX7YK0EBOSF7/session_pos_1b_accuracy.csv
# Saved per-session/obj stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1LX7YK0EBOSF7/session_obj_accuracy.csv
#
# === Analyzing A1NRDN6SEGOTGA performance on (interdms_position_identity) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 52.50%
# Overall (per-frame) accuracy:      52.50%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20           0.550           0.550          1
#        2        20           0.500           0.500          0
#        3        20           0.575           0.575          0
#        4        20           0.475           0.475          0
#        5        20           0.525           0.525          0
#
# Per-pos_1b accuracy per session:
#  session  pos_1b  n_samples  accuracy  n_missing
#        1       1          3  0.666667          0
#        1       2          3  0.666667          0
#        1       3          4  0.000000          0
#        1       4          1  1.000000          0
#        1       5         19  0.578947          1
#        1       6          2  0.500000          0
#        1       7          1  1.000000          0
#        1       8          5  0.600000          0
#        1       9          2  0.500000          0
#        2       1          1  1.000000          0
#        2       2          2  0.500000          0
#        2       3          4  0.750000          0
#        2       4          1  0.000000          0
#        2       5         19  0.526316          0
#        2       6          1  1.000000          0
#        2       7          6  0.500000          0
#        2       8          4  0.250000          0
#        2       9          2  0.000000          0
#        3       1          2  1.000000          0
#        3       2          1  1.000000          0
#        3       3          5  0.400000          0
#        3       4          4  0.250000          0
#        3       5         15  0.666667          0
#        3       6          5  0.600000          0
#        3       7          5  0.400000          0
#        3       8          2  0.500000          0
#        3       9          1  1.000000          0
#        4       1          3  0.666667          0
#        4       2          1  0.000000          0
#        4       3          3  0.333333          0
#        4       4          7  0.285714          0
#        4       5         15  0.533333          0
#        4       6          3  0.666667          0
#        4       7          5  0.400000          0
#        4       8          2  0.500000          0
#        4       9          1  1.000000          0
#        5       1          1  1.000000          0
#        5       2          1  0.000000          0
#        5       3          3  0.666667          0
#        5       4          1  0.000000          0
#        5       5         24  0.583333          0
#        5       6          4  0.000000          0
#        5       7          3  0.666667          0
#        5       8          1  0.000000          0
#        5       9          2  1.000000          0
#
# Per-obj accuracy per session:
#  session                      obj  n_samples  accuracy  n_missing
#        1          Apple_Fruit_obj          2  1.000000          0
#        1                   Beetle          1  1.000000          0
#        1                  GORILLA          1  1.000000          0
#        1                 MQUEEN_L          1  0.000000          0
#        1           Strawberry_obj          1  0.000000          0
#        1                 TURTLE_L          1  1.000000          0
#        1                     _001          1  0.000000          0
#        1                     _010          1  1.000000          0
#        1                     _014          2  1.000000          0
#        1 _01_Airliner_2jetEngines          2  0.500000          0
#        1               _05_future          1  0.000000          0
#        1                      _08          2  0.500000          0
#        1                      _18          2  0.500000          0
#        1                      _37          1  1.000000          0
#        1                      _44          1  0.000000          1
#        1                   celica          2  0.500000          0
#        1                  cruiser          3  0.666667          0
#        1                 face0001          2  0.500000          0
#        1                 face0004          1  0.000000          0
#        1                 hedgehog          2  1.000000          0
#        1                junkers88          3  0.000000          0
#        1                    mig29          1  1.000000          0
#        1            raspberry_obj          2  0.500000          0
#        1                 rdbarren          2  0.500000          0
#        1               walnut_obj          2  0.500000          0
#        2          Apple_Fruit_obj          1  1.000000          0
#        2                   Beetle          1  0.000000          0
#        2               ELEPHANT_M          2  0.500000          0
#        2                  GORILLA          2  0.000000          0
#        2                Peach_obj          1  0.000000          0
#        2                 SISTER_L          2  0.500000          0
#        2                 TURTLE_L          2  0.500000          0
#        2                     _010          1  0.000000          0
#        2 _01_Airliner_2jetEngines          1  1.000000          0
#        2                     _031          1  0.000000          0
#        2                     _033          2  0.500000          0
#        2               _05_future          1  0.000000          0
#        2                      _08          2  1.000000          0
#        2                      _10          1  1.000000          0
#        2                      _11          1  0.000000          0
#        2                      _37          2  0.500000          0
#        2                      _44          1  0.000000          0
#        2                  alfa155          1  1.000000          0
#        2                   bmw325          1  0.000000          0
#        2                   celica          1  0.000000          0
#        2                      f16          1  1.000000          0
#        2                 face0001          1  0.000000          0
#        2                 face0004          1  1.000000          0
#        2                 face0005          1  1.000000          0
#        2                 face0006          2  0.500000          0
#        2                 face0008          1  1.000000          0
#        2                 hedgehog          2  0.500000          0
#        2                junkers88          1  1.000000          0
#        2                    mig29          1  1.000000          0
#        2               walnut_obj          1  1.000000          0
#        2           watermelon_obj          1  0.000000          0
#        3          Apple_Fruit_obj          2  0.500000          0
#        3                   Beetle          1  1.000000          0
#        3               ELEPHANT_M          2  1.000000          0
#        3                Peach_obj          2  1.000000          0
#        3           Strawberry_obj          1  0.000000          0
#        3                     _001          1  1.000000          0
#        3                     _010          2  0.000000          0
#        3                     _014          1  1.000000          0
#        3 _01_Airliner_2jetEngines          1  0.000000          0
#        3                     _031          1  0.000000          0
#        3               _05_future          1  1.000000          0
#        3                      _18          2  0.000000          0
#        3                      _37          1  0.000000          0
#        3                  alfa155          2  0.500000          0
#        3                     bear          3  0.666667          0
#        3                   bmw325          2  1.000000          0
#        3                   celica          1  1.000000          0
#        3                      f16          1  1.000000          0
#        3                 face0001          1  0.000000          0
#        3                 face0002          1  0.000000          0
#        3                 face0004          1  1.000000          0
#        3                 face0006          1  0.000000          0
#        3                 face0008          3  1.000000          0
#        3               motoryacht          1  1.000000          0
#        3            raspberry_obj          2  0.500000          0
#        3                  sopwith          1  1.000000          0
#        3           watermelon_obj          1  0.000000          0
#        3                       z3          1  0.000000          0
#        4          Apple_Fruit_obj          1  1.000000          0
#        4                  BAHRAIN          1  0.000000          0
#        4               ELEPHANT_M          1  1.000000          0
#        4                 MQUEEN_L          2  0.000000          0
#        4                Peach_obj          2  0.500000          0
#        4                 SISTER_L          2  0.500000          0
#        4           Strawberry_obj          1  0.000000          0
#        4                     _001          1  0.000000          0
#        4                     _010          1  0.000000          0
#        4                     _011          1  0.000000          0
#        4                     _014          2  1.000000          0
#        4                     _031          1  1.000000          0
#        4                     _033          2  0.000000          0
#        4               _05_future          1  1.000000          0
#        4                      _12          2  0.500000          0
#        4                      _37          1  0.000000          0
#        4                     bear          2  0.500000          0
#        4                     clio          3  0.666667          0
#        4                 face0004          2  1.000000          0
#        4                 face0005          1  1.000000          0
#        4                 face0008          1  1.000000          0
#        4            raspberry_obj          2  0.500000          0
#        4                 rdbarren          1  1.000000          0
#        4                  sopwith          1  0.000000          0
#        4               walnut_obj          2  0.500000          0
#        4           watermelon_obj          3  0.000000          0
#        5          Apple_Fruit_obj          1  0.000000          0
#        5                  BAHRAIN          2  0.500000          0
#        5                   Beetle          2  0.500000          0
#        5               ELEPHANT_M          1  1.000000          0
#        5                  GORILLA          1  1.000000          0
#        5                Peach_obj          2  1.000000          0
#        5                     _001          2  0.500000          0
#        5                     _010          1  1.000000          0
#        5                     _031          1  1.000000          0
#        5               _05_future          2  1.000000          0
#        5                      _11          2  0.500000          0
#        5                      _37          2  0.500000          0
#        5                      _44          2  0.500000          0
#        5                     bear          1  0.000000          0
#        5                    blCow          1  1.000000          0
#        5                   bmw325          2  0.000000          0
#        5                 face0004          1  1.000000          0
#        5                 face0005          1  1.000000          0
#        5                 face0006          1  0.000000          0
#        5                 face0008          1  0.000000          0
#        5                 hedgehog          1  0.000000          0
#        5                junkers88          1  0.000000          0
#        5                    mig29          1  1.000000          0
#        5            raspberry_obj          2  0.000000          0
#        5               walnut_obj          1  0.000000          0
#        5           watermelon_obj          3  0.333333          0
#        5                       z3          2  1.000000          0
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1NRDN6SEGOTGA/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1NRDN6SEGOTGA/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1NRDN6SEGOTGA/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1NRDN6SEGOTGA/session_summary.csv
# Saved per-session/pos_1b stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1NRDN6SEGOTGA/session_pos_1b_accuracy.csv
# Saved per-session/obj stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A1NRDN6SEGOTGA/session_obj_accuracy.csv
#
# === Analyzing A2ACGF53MHGQ1K performance on (interdms_position_identity) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 45.50%
# Overall (per-frame) accuracy:      45.50%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20           0.325           0.325          5
#        2        20           0.425           0.425          1
#        3        20           0.550           0.550          0
#        4        20           0.600           0.600          0
#        5        20           0.375           0.375          0
#
# Per-pos_1b accuracy per session:
#  session  pos_1b  n_samples  accuracy  n_missing
#        1       1          3  0.333333          0
#        1       2          3  0.666667          0
#        1       3          4  0.750000          0
#        1       4          1  0.000000          0
#        1       5         19  0.263158          2
#        1       6          2  0.000000          0
#        1       7          1  0.000000          0
#        1       8          5  0.200000          3
#        1       9          2  0.500000          0
#        2       1          1  1.000000          0
#        2       2          2  0.500000          0
#        2       3          4  0.750000          1
#        2       4          1  1.000000          0
#        2       5         19  0.421053          0
#        2       6          1  0.000000          0
#        2       7          6  0.166667          0
#        2       8          4  0.500000          0
#        2       9          2  0.000000          0
#        3       1          2  1.000000          0
#        3       2          1  1.000000          0
#        3       3          5  0.600000          0
#        3       4          4  0.250000          0
#        3       5         15  0.466667          0
#        3       6          5  0.600000          0
#        3       7          5  0.600000          0
#        3       8          2  0.500000          0
#        3       9          1  1.000000          0
#        4       1          3  0.333333          0
#        4       2          1  1.000000          0
#        4       3          3  0.666667          0
#        4       4          7  0.428571          0
#        4       5         15  0.600000          0
#        4       6          3  0.333333          0
#        4       7          5  1.000000          0
#        4       8          2  0.500000          0
#        4       9          1  1.000000          0
#        5       1          1  0.000000          0
#        5       2          1  1.000000          0
#        5       3          3  0.333333          0
#        5       4          1  1.000000          0
#        5       5         24  0.375000          0
#        5       6          4  0.500000          0
#        5       7          3  0.000000          0
#        5       8          1  0.000000          0
#        5       9          2  0.500000          0
#
# Per-obj accuracy per session:
#  session                      obj  n_samples  accuracy  n_missing
#        1          Apple_Fruit_obj          2  0.000000          0
#        1                   Beetle          1  0.000000          0
#        1                  GORILLA          1  1.000000          0
#        1                 MQUEEN_L          1  0.000000          0
#        1           Strawberry_obj          1  0.000000          0
#        1                 TURTLE_L          1  0.000000          1
#        1                     _001          1  0.000000          0
#        1                     _010          1  0.000000          0
#        1                     _014          2  0.000000          0
#        1 _01_Airliner_2jetEngines          2  0.500000          0
#        1               _05_future          1  0.000000          0
#        1                      _08          2  0.000000          1
#        1                      _18          2  0.500000          0
#        1                      _37          1  0.000000          0
#        1                      _44          1  0.000000          1
#        1                   celica          2  1.000000          0
#        1                  cruiser          3  0.666667          0
#        1                 face0001          2  0.000000          1
#        1                 face0004          1  1.000000          0
#        1                 hedgehog          2  0.500000          0
#        1                junkers88          3  0.666667          0
#        1                    mig29          1  1.000000          0
#        1            raspberry_obj          2  0.500000          1
#        1                 rdbarren          2  0.000000          0
#        1               walnut_obj          2  0.000000          0
#        2          Apple_Fruit_obj          1  0.000000          0
#        2                   Beetle          1  1.000000          0
#        2               ELEPHANT_M          2  0.500000          0
#        2                  GORILLA          2  0.500000          0
#        2                Peach_obj          1  1.000000          0
#        2                 SISTER_L          2  0.500000          0
#        2                 TURTLE_L          2  1.000000          0
#        2                     _010          1  0.000000          0
#        2 _01_Airliner_2jetEngines          1  0.000000          0
#        2                     _031          1  1.000000          0
#        2                     _033          2  0.000000          0
#        2               _05_future          1  0.000000          0
#        2                      _08          2  1.000000          0
#        2                      _10          1  0.000000          0
#        2                      _11          1  0.000000          0
#        2                      _37          2  0.500000          0
#        2                      _44          1  1.000000          0
#        2                  alfa155          1  1.000000          0
#        2                   bmw325          1  0.000000          0
#        2                   celica          1  0.000000          0
#        2                      f16          1  1.000000          0
#        2                 face0001          1  0.000000          0
#        2                 face0004          1  0.000000          1
#        2                 face0005          1  1.000000          0
#        2                 face0006          2  0.000000          0
#        2                 face0008          1  0.000000          0
#        2                 hedgehog          2  0.500000          0
#        2                junkers88          1  0.000000          0
#        2                    mig29          1  1.000000          0
#        2               walnut_obj          1  0.000000          0
#        2           watermelon_obj          1  0.000000          0
#        3          Apple_Fruit_obj          2  0.000000          0
#        3                   Beetle          1  0.000000          0
#        3               ELEPHANT_M          2  0.500000          0
#        3                Peach_obj          2  0.500000          0
#        3           Strawberry_obj          1  0.000000          0
#        3                     _001          1  0.000000          0
#        3                     _010          2  0.500000          0
#        3                     _014          1  1.000000          0
#        3 _01_Airliner_2jetEngines          1  0.000000          0
#        3                     _031          1  1.000000          0
#        3               _05_future          1  1.000000          0
#        3                      _18          2  1.000000          0
#        3                      _37          1  0.000000          0
#        3                  alfa155          2  0.500000          0
#        3                     bear          3  1.000000          0
#        3                   bmw325          2  0.500000          0
#        3                   celica          1  0.000000          0
#        3                      f16          1  1.000000          0
#        3                 face0001          1  0.000000          0
#        3                 face0002          1  1.000000          0
#        3                 face0004          1  0.000000          0
#        3                 face0006          1  1.000000          0
#        3                 face0008          3  0.666667          0
#        3               motoryacht          1  1.000000          0
#        3            raspberry_obj          2  0.500000          0
#        3                  sopwith          1  1.000000          0
#        3           watermelon_obj          1  0.000000          0
#        3                       z3          1  1.000000          0
#        4          Apple_Fruit_obj          1  1.000000          0
#        4                  BAHRAIN          1  0.000000          0
#        4               ELEPHANT_M          1  0.000000          0
#        4                 MQUEEN_L          2  0.000000          0
#        4                Peach_obj          2  0.500000          0
#        4                 SISTER_L          2  1.000000          0
#        4           Strawberry_obj          1  0.000000          0
#        4                     _001          1  0.000000          0
#        4                     _010          1  1.000000          0
#        4                     _011          1  1.000000          0
#        4                     _014          2  1.000000          0
#        4                     _031          1  1.000000          0
#        4                     _033          2  0.500000          0
#        4               _05_future          1  1.000000          0
#        4                      _12          2  1.000000          0
#        4                      _37          1  0.000000          0
#        4                     bear          2  1.000000          0
#        4                     clio          3  0.666667          0
#        4                 face0004          2  1.000000          0
#        4                 face0005          1  0.000000          0
#        4                 face0008          1  1.000000          0
#        4            raspberry_obj          2  1.000000          0
#        4                 rdbarren          1  0.000000          0
#        4                  sopwith          1  1.000000          0
#        4               walnut_obj          2  0.500000          0
#        4           watermelon_obj          3  0.000000          0
#        5          Apple_Fruit_obj          1  1.000000          0
#        5                  BAHRAIN          2  0.000000          0
#        5                   Beetle          2  0.500000          0
#        5               ELEPHANT_M          1  0.000000          0
#        5                  GORILLA          1  1.000000          0
#        5                Peach_obj          2  0.000000          0
#        5                     _001          2  1.000000          0
#        5                     _010          1  0.000000          0
#        5                     _031          1  1.000000          0
#        5               _05_future          2  0.000000          0
#        5                      _11          2  0.500000          0
#        5                      _37          2  0.000000          0
#        5                      _44          2  0.000000          0
#        5                     bear          1  1.000000          0
#        5                    blCow          1  0.000000          0
#        5                   bmw325          2  0.000000          0
#        5                 face0004          1  0.000000          0
#        5                 face0005          1  0.000000          0
#        5                 face0006          1  1.000000          0
#        5                 face0008          1  0.000000          0
#        5                 hedgehog          1  1.000000          0
#        5                junkers88          1  1.000000          0
#        5                    mig29          1  0.000000          0
#        5            raspberry_obj          2  0.500000          0
#        5               walnut_obj          1  0.000000          0
#        5           watermelon_obj          3  0.333333          0
#        5                       z3          2  1.000000          0
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2ACGF53MHGQ1K/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2ACGF53MHGQ1K/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2ACGF53MHGQ1K/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2ACGF53MHGQ1K/session_summary.csv
# Saved per-session/pos_1b stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2ACGF53MHGQ1K/session_pos_1b_accuracy.csv
# Saved per-session/obj stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/A2ACGF53MHGQ1K/session_obj_accuracy.csv
#
# === Analyzing A2G4TQWINTVEWZ performance on (interdms_position_identity) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 43.50%
# Overall (per-frame) accuracy:      43.50%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20           0.400           0.400          5
#        2        20           0.375           0.375          0
#        3        20           0.525           0.525          0
#        4        20           0.475           0.475          0
#        5        20           0.400           0.400          2
#
# Per-pos_1b accuracy per session:
#  session  pos_1b  n_samples  accuracy  n_missing
#        1       1          3  0.000000          1
#        1       2          3  0.333333          0
#        1       3          4  0.250000          0
#        1       4          1  1.000000          0
#        1       5         19  0.368421          2
#        1       6          2  0.500000          1
#        1       7          1  0.000000          0
#        1       8          5  0.800000          0
#        1       9          2  0.500000          1
#        2       1          1  0.000000          0
#        2       2          2  0.500000          0
#        2       3          4  0.750000          0
#        2       4          1  0.000000          0
#        2       5         19  0.263158          0
#        2       6          1  0.000000          0
#        2       7          6  0.500000          0
#        2       8          4  0.500000          0
#        2       9          2  0.500000          0
#        3       1          2  1.000000          0
#        3       2          1  1.000000          0
#        3       3          5  0.800000          0
#        3       4          4  0.250000          0
#        3       5         15  0.400000          0
#        3       6          5  0.400000          0
#        3       7          5  0.400000          0
#        3       8          2  1.000000          0
#        3       9          1  1.000000          0
#        4       1          3  0.000000          0
#        4       2          1  1.000000          0
#        4       3          3  0.333333          0
#        4       4          7  0.428571          0
#        4       5         15  0.400000          0
#        4       6          3  0.666667          0
#        4       7          5  0.800000          0
#        4       8          2  1.000000          0
#        4       9          1  0.000000          0
#        5       1          1  0.000000          0
#        5       2          1  0.000000          0
#        5       3          3  0.000000          0
#        5       4          1  1.000000          0
#        5       5         24  0.458333          1
#        5       6          4  0.500000          0
#        5       7          3  0.333333          1
#        5       8          1  0.000000          0
#        5       9          2  0.500000          0
#
# Per-obj accuracy per session:
#  session                      obj  n_samples  accuracy  n_missing
#        1          Apple_Fruit_obj          2  0.000000          0
#        1                   Beetle          1  1.000000          0
#        1                  GORILLA          1  1.000000          0
#        1                 MQUEEN_L          1  1.000000          0
#        1           Strawberry_obj          1  0.000000          0
#        1                 TURTLE_L          1  1.000000          0
#        1                     _001          1  0.000000          1
#        1                     _010          1  0.000000          0
#        1                     _014          2  0.500000          1
#        1 _01_Airliner_2jetEngines          2  0.500000          0
#        1               _05_future          1  0.000000          1
#        1                      _08          2  0.000000          0
#        1                      _18          2  0.000000          0
#        1                      _37          1  1.000000          0
#        1                      _44          1  0.000000          0
#        1                   celica          2  0.500000          0
#        1                  cruiser          3  0.333333          1
#        1                 face0001          2  1.000000          0
#        1                 face0004          1  0.000000          0
#        1                 hedgehog          2  0.000000          0
#        1                junkers88          3  0.333333          0
#        1                    mig29          1  0.000000          0
#        1            raspberry_obj          2  0.500000          0
#        1                 rdbarren          2  0.500000          1
#        1               walnut_obj          2  1.000000          0
#        2          Apple_Fruit_obj          1  0.000000          0
#        2                   Beetle          1  0.000000          0
#        2               ELEPHANT_M          2  1.000000          0
#        2                  GORILLA          2  0.000000          0
#        2                Peach_obj          1  0.000000          0
#        2                 SISTER_L          2  1.000000          0
#        2                 TURTLE_L          2  0.000000          0
#        2                     _010          1  1.000000          0
#        2 _01_Airliner_2jetEngines          1  0.000000          0
#        2                     _031          1  1.000000          0
#        2                     _033          2  0.500000          0
#        2               _05_future          1  1.000000          0
#        2                      _08          2  1.000000          0
#        2                      _10          1  0.000000          0
#        2                      _11          1  0.000000          0
#        2                      _37          2  0.000000          0
#        2                      _44          1  1.000000          0
#        2                  alfa155          1  1.000000          0
#        2                   bmw325          1  0.000000          0
#        2                   celica          1  1.000000          0
#        2                      f16          1  0.000000          0
#        2                 face0001          1  0.000000          0
#        2                 face0004          1  0.000000          0
#        2                 face0005          1  0.000000          0
#        2                 face0006          2  0.500000          0
#        2                 face0008          1  0.000000          0
#        2                 hedgehog          2  0.500000          0
#        2                junkers88          1  0.000000          0
#        2                    mig29          1  0.000000          0
#        2               walnut_obj          1  0.000000          0
#        2           watermelon_obj          1  0.000000          0
#        3          Apple_Fruit_obj          2  0.000000          0
#        3                   Beetle          1  0.000000          0
#        3               ELEPHANT_M          2  0.500000          0
#        3                Peach_obj          2  1.000000          0
#        3           Strawberry_obj          1  0.000000          0
#        3                     _001          1  0.000000          0
#        3                     _010          2  0.500000          0
#        3                     _014          1  1.000000          0
#        3 _01_Airliner_2jetEngines          1  0.000000          0
#        3                     _031          1  1.000000          0
#        3               _05_future          1  1.000000          0
#        3                      _18          2  0.500000          0
#        3                      _37          1  0.000000          0
#        3                  alfa155          2  1.000000          0
#        3                     bear          3  0.333333          0
#        3                   bmw325          2  0.500000          0
#        3                   celica          1  1.000000          0
#        3                      f16          1  1.000000          0
#        3                 face0001          1  0.000000          0
#        3                 face0002          1  1.000000          0
#        3                 face0004          1  1.000000          0
#        3                 face0006          1  0.000000          0
#        3                 face0008          3  0.333333          0
# ...
#        4                     clio          3  0.000000          2
#        4                 face0004          2  0.000000          2
#        4                 face0005          1  0.000000          0
#        4                 face0008          1  0.000000          1
#        4            raspberry_obj          2  0.000000          1
#        4                 rdbarren          1  0.000000          0
#        4                  sopwith          1  0.000000          1
#        4               walnut_obj          2  0.500000          1
#        4           watermelon_obj          3  0.000000          2
#        5          Apple_Fruit_obj          1  0.000000          1
#        5                  BAHRAIN          2  0.500000          1
#        5                   Beetle          2  0.000000          0
#        5               ELEPHANT_M          1  0.000000          1
#        5                  GORILLA          1  1.000000          0
#        5                Peach_obj          2  0.500000          1
#        5                     _001          2  0.000000          2
#        5                     _010          1  1.000000          0
#        5                     _031          1  0.000000          1
#        5               _05_future          2  0.000000          1
#        5                      _11          2  0.000000          2
#        5                      _37          2  0.000000          2
#        5                      _44          2  0.500000          1
#        5                     bear          1  0.000000          1
#        5                    blCow          1  1.000000          0
#        5                   bmw325          2  0.000000          1
#        5                 face0004          1  1.000000          0
#        5                 face0005          1  1.000000          0
#        5                 face0006          1  0.000000          1
#        5                 face0008          1  0.000000          1
#        5                 hedgehog          1  0.000000          1
#        5                junkers88          1  0.000000          1
#        5                    mig29          1  0.000000          1
#        5            raspberry_obj          2  0.000000          2
#        5               walnut_obj          1  0.000000          1
#        5           watermelon_obj          3  0.000000          2
#        5                       z3          2  0.500000          1
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/ACQU0SPM3WZ5H/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/ACQU0SPM3WZ5H/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/ACQU0SPM3WZ5H/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/ACQU0SPM3WZ5H/session_summary.csv
# Saved per-session/pos_1b stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/ACQU0SPM3WZ5H/session_pos_1b_accuracy.csv
# Saved per-session/obj stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/ACQU0SPM3WZ5H/session_obj_accuracy.csv
#
# === Analyzing AH7A6WY6V76KP performance on (interdms_position_identity) ===
#
# Analyzed 100 trials
# Overall (mean per-trial) accuracy: 5.00%
# Overall (per-frame) accuracy:      5.00%
#
# Session-level summary:
#  session  n_trials  frame_accuracy  trial_accuracy  n_missing
#        1        20            0.15            0.15         31
#        2        20            0.10            0.10         31
#        3        20            0.00            0.00         40
#        4        20            0.00            0.00         40
#        5        20            0.00            0.00         40
#
# Per-pos_1b accuracy per session:
#  session  pos_1b  n_samples  accuracy  n_missing
#        1       1          3  0.000000          3
#        1       2          3  0.000000          3
#        1       3          4  0.500000          2
#        1       4          1  0.000000          1
#        1       5         19  0.105263         15
#        1       6          2  0.000000          2
#        1       7          1  0.000000          1
#        1       8          5  0.200000          3
#        1       9          2  0.500000          1
#        2       1          1  0.000000          1
#        2       2          2  0.000000          2
#        2       3          4  0.250000          3
#        2       4          1  0.000000          1
#        2       5         19  0.105263         14
#        2       6          1  0.000000          1
#        2       7          6  0.000000          6
#        2       8          4  0.250000          2
#        2       9          2  0.000000          1
#        3       1          2  0.000000          2
#        3       2          1  0.000000          1
#        3       3          5  0.000000          5
#        3       4          4  0.000000          4
#        3       5         15  0.000000         15
#        3       6          5  0.000000          5
#        3       7          5  0.000000          5
#        3       8          2  0.000000          2
#        3       9          1  0.000000          1
#        4       1          3  0.000000          3
#        4       2          1  0.000000          1
#        4       3          3  0.000000          3
#        4       4          7  0.000000          7
#        4       5         15  0.000000         15
#        4       6          3  0.000000          3
#        4       7          5  0.000000          5
#        4       8          2  0.000000          2
#        4       9          1  0.000000          1
#        5       1          1  0.000000          1
#        5       2          1  0.000000          1
#        5       3          3  0.000000          3
#        5       4          1  0.000000          1
#        5       5         24  0.000000         24
#        5       6          4  0.000000          4
#        5       7          3  0.000000          3
#        5       8          1  0.000000          1
#        5       9          2  0.000000          2
#
# Per-obj accuracy per session:
#  session                      obj  n_samples  accuracy  n_missing
#        1          Apple_Fruit_obj          2  0.000000          2
#        1                   Beetle          1  0.000000          1
#        1                  GORILLA          1  1.000000          0
#        1                 MQUEEN_L          1  0.000000          0
#        1           Strawberry_obj          1  0.000000          1
#        1                 TURTLE_L          1  1.000000          0
#        1                     _001          1  0.000000          1
#        1                     _010          1  0.000000          1
#        1                     _014          2  0.000000          2
#        1 _01_Airliner_2jetEngines          2  0.000000          2
#        1               _05_future          1  0.000000          1
#        1                      _08          2  0.500000          1
#        1                      _18          2  0.500000          1
#        1                      _37          1  0.000000          1
#        1                      _44          1  0.000000          1
#        1                   celica          2  0.000000          2
#        1                  cruiser          3  0.000000          3
#        1                 face0001          2  0.000000          1
#        1                 face0004          1  0.000000          0
#        1                 hedgehog          2  0.000000          2
#        1                junkers88          3  0.333333          2
#        1                    mig29          1  0.000000          1
#        1            raspberry_obj          2  0.000000          2
#        1                 rdbarren          2  0.500000          1
#        1               walnut_obj          2  0.000000          2
#        2          Apple_Fruit_obj          1  0.000000          1
#        2                   Beetle          1  0.000000          0
#        2               ELEPHANT_M          2  0.500000          1
#        2                  GORILLA          2  0.000000          2
#        2                Peach_obj          1  0.000000          1
#        2                 SISTER_L          2  0.000000          2
#        2                 TURTLE_L          2  0.000000          2
#        2                     _010          1  0.000000          1
#        2 _01_Airliner_2jetEngines          1  1.000000          0
#        2                     _031          1  0.000000          1
#        2                     _033          2  0.500000          1
#        2               _05_future          1  0.000000          0
#        2                      _08          2  0.500000          1
#        2                      _10          1  0.000000          1
#        2                      _11          1  0.000000          0
#        2                      _37          2  0.000000          2
#        2                      _44          1  0.000000          0
#        2                  alfa155          1  0.000000          1
#        2                   bmw325          1  0.000000          1
#        2                   celica          1  0.000000          1
#        2                      f16          1  0.000000          1
#        2                 face0001          1  0.000000          1
#        2                 face0004          1  0.000000          1
#        2                 face0005          1  0.000000          1
#        2                 face0006          2  0.000000          2
#        2                 face0008          1  0.000000          1
#        2                 hedgehog          2  0.000000          2
#        2                junkers88          1  0.000000          1
#        2                    mig29          1  0.000000          0
#        2               walnut_obj          1  0.000000          1
#        2           watermelon_obj          1  0.000000          1
#        3          Apple_Fruit_obj          2  0.000000          2
#        3                   Beetle          1  0.000000          1
#        3               ELEPHANT_M          2  0.000000          2
#        3                Peach_obj          2  0.000000          2
#        3           Strawberry_obj          1  0.000000          1
#        3                     _001          1  0.000000          1
#        3                     _010          2  0.000000          2
#        3                     _014          1  0.000000          1
#        3 _01_Airliner_2jetEngines          1  0.000000          1
#        3                     _031          1  0.000000          1
#        3               _05_future          1  0.000000          1
#        3                      _18          2  0.000000          2
#        3                      _37          1  0.000000          1
#        3                  alfa155          2  0.000000          2
#        3                     bear          3  0.000000          3
#        3                   bmw325          2  0.000000          2
#        3                   celica          1  0.000000          1
#        3                      f16          1  0.000000          1
#        3                 face0001          1  0.000000          1
#        3                 face0002          1  0.000000          1
#        3                 face0004          1  0.000000          1
#        3                 face0006          1  0.000000          1
#        3                 face0008          3  0.000000          3
#        3               motoryacht          1  0.000000          1
#        3            raspberry_obj          2  0.000000          2
#        3                  sopwith          1  0.000000          1
#        3           watermelon_obj          1  0.000000          1
#        3                       z3          1  0.000000          1
#        4          Apple_Fruit_obj          1  0.000000          1
#        4                  BAHRAIN          1  0.000000          1
#        4               ELEPHANT_M          1  0.000000          1
#        4                 MQUEEN_L          2  0.000000          2
#        4                Peach_obj          2  0.000000          2
#        4                 SISTER_L          2  0.000000          2
#        4           Strawberry_obj          1  0.000000          1
#        4                     _001          1  0.000000          1
#        4                     _010          1  0.000000          1
#        4                     _011          1  0.000000          1
#        4                     _014          2  0.000000          2
#        4                     _031          1  0.000000          1
#        4                     _033          2  0.000000          2
#        4               _05_future          1  0.000000          1
#        4                      _12          2  0.000000          2
#        4                      _37          1  0.000000          1
#        4                     bear          2  0.000000          2
#        4                     clio          3  0.000000          3
#        4                 face0004          2  0.000000          2
#        4                 face0005          1  0.000000          1
#        4                 face0008          1  0.000000          1
#        4            raspberry_obj          2  0.000000          2
#        4                 rdbarren          1  0.000000          1
#        4                  sopwith          1  0.000000          1
#        4               walnut_obj          2  0.000000          2
#        4           watermelon_obj          3  0.000000          3
#        5          Apple_Fruit_obj          1  0.000000          1
#        5                  BAHRAIN          2  0.000000          2
#        5                   Beetle          2  0.000000          2
#        5               ELEPHANT_M          1  0.000000          1
#        5                  GORILLA          1  0.000000          1
#        5                Peach_obj          2  0.000000          2
#        5                     _001          2  0.000000          2
#        5                     _010          1  0.000000          1
#        5                     _031          1  0.000000          1
#        5               _05_future          2  0.000000          2
#        5                      _11          2  0.000000          2
#        5                      _37          2  0.000000          2
#        5                      _44          2  0.000000          2
#        5                     bear          1  0.000000          1
#        5                    blCow          1  0.000000          1
#        5                   bmw325          2  0.000000          2
#        5                 face0004          1  0.000000          1
#        5                 face0005          1  0.000000          1
#        5                 face0006          1  0.000000          1
#        5                 face0008          1  0.000000          1
#        5                 hedgehog          1  0.000000          1
#        5                junkers88          1  0.000000          1
#        5                    mig29          1  0.000000          1
#        5            raspberry_obj          2  0.000000          2
#        5               walnut_obj          1  0.000000          1
#        5           watermelon_obj          3  0.000000          3
#        5                       z3          2  0.000000          2
#
# Saved RT distribution plot to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AH7A6WY6V76KP/rt_distribution.png
# Saved per-trial accuracy to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AH7A6WY6V76KP/trial_accuracy.csv
# Saved detailed responses to:    /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AH7A6WY6V76KP/detailed_accuracy.csv
# Saved per-session summary to:   /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AH7A6WY6V76KP/session_summary.csv
# Saved per-session/pos_1b stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AH7A6WY6V76KP/session_pos_1b_accuracy.csv
# Saved per-session/obj stats to: /Users/markbai/PycharmProjects/abs_nat_psychopy_mturk/data/AH7A6WY6V76KP/session_obj_accuracy.csv
#
# ✅ Done running analysis for all available response files.
